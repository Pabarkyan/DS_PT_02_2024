# %%
texto = "Una vez ejecutada esta celda, la variable texto estará en memoria mientras dure la __sesión__"
print(texto)
# Out:
# Una vez ejecutada esta celda, la variable texto estará en memoria mientras dure la __sesión__

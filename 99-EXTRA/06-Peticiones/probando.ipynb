# %%
# Existe otras librerias que calculan las distancias de todos los elementos de un array dos a dos!!!
from haversine import haversine_vector, Unit

lyon = (45.7597, 4.8422) # (latitude, longitude)
paris = (48.8567, 2.3508)
new_york = (40.7033962, -74.2351462)

haversine_vector([lyon, lyon], [paris, new_york], Unit.KILOMETERS)
# Out:
# array([ 392.21725956, 6163.43638211])

# %%
# Solo muestra: hay que buscar las librerias de python que hacen esto con mucha más potencia
f = open("el_quijote.txt", "r", encoding="latin-1")
dict_quijote = {}
for linea in f:
  linea = linea.split()
  for c in linea:
    if c in dict_quijote.keys():
      dict_quijote[c] += 1
    else:
      dict_quijote[c] = 1

# %%
dict_quijote
# Out:
# {'DON': 6,
#  'QUIJOTE': 6,
#  'DE': 17,
#  'LA': 13,
#  'MANCHA': 2,
#  'Miguel': 3,
#  'de': 8947,
#  'Cervantes': 1,
#  'Saavedra': 1,
#  'PRIMERA': 1,
#  'PARTE': 1,
#  'CAPIÌ\x81TULO': 1,
#  '1:': 1,
#  'Que': 33,
#  'trata': 21,
#  'la': 4941,
#  'condicioÌ\x81n': 23,
#  'y': 8042,
#  'ejercicio': 18,
#  'del': 1113,
#  'famoso': 49,
#  'hidalgo': 16,
#  'D.': 14,
#  'Quijote': 310,
#  'Mancha': 11,
#  'En': 143,
#  'un': 894,
#  'lugar': 137,
#  'Mancha,': 28,
#  'cuyo': 26,
#  'nombre': 67,
#  'no': 2786,
#  'quiero': 97,
#  'acordarme,': 1,
#  'ha': 460,
#  'mucho': 141,
#  'tiempo': 139,
#  'que': 10351,
#  'viviÌ\x81a': 10,
#  'los': 2122,
#  'lanza': 17,
#  'en': 3883,
#  'astillero,': 1,
#  'adarga': 7,
#  'antigua,': 1,
#  'rociÌ\x81n': 5,
#  'flaco': 2,
#  'galgo': 2,
#  'corredor.': 1,
#  'Una': 2,
#  'olla': 2,
#  'algo': 55,
#  'maÌ\x81s': 882,
#  'vaca': 1,
#  'carnero,': 1,
#  'salpicoÌ\x81n': 1,
#  'las': 1473,
#  'noches,': 3,
#  'duelos': 1,
# ...

# %% [markdown]
# # REST APIs con Python

# %% [markdown]
# Hay una cantidad increíble de datos disponibles en la web. Muchos servicios web, como YouTube y GitHub, hacen que sus datos sean accesibles a aplicaciones de terceros a través de una interfaz de programación de aplicaciones (API). Una de las formas más populares de construir APIs es con el estilo de arquitectura REST. Python proporciona algunas herramientas excelentes no sólo para obtener datos de las APIs REST, sino también para construir tus propias APIs REST en Python.
#
# Utilizando Python y las APIs REST, puedes recuperar, analizar, actualizar y manipular los datos proporcionados por cualquier servicio web que te interese.

# %% [markdown]
# ## Arquitectura REST y servicios Web REST

# %% [markdown]
# REST significa [representational state transfer](https://en.wikipedia.org/wiki/Representational_state_transfer) y es un estilo de arquitectura de software que define un patrón para las comunicaciones entre cliente y servidor a través de una red. REST proporciona un conjunto de restricciones para que la arquitectura del software promueva el rendimiento, la escalabilidad, la simplicidad y la fiabilidad del sistema.

# %% [markdown]
# Un servicio web REST es cualquier servicio web que se adhiere a las restricciones de la arquitectura REST. Estos servicios web exponen sus datos al mundo exterior a través de una API. Las APIs REST proporcionan acceso a los datos del servicio web a través de URLs web públicas.
#
# Por ejemplo, esta es una de las URL de la API REST de GitHub:
#
# ```
# https://api.github.com/users/<nombredeusuario>
# ```
#
# Esta URL te permite acceder a información sobre un usuario específico de GitHub. El acceso a los datos de una API REST se realiza enviando una solicitud HTTP a una URL específica y procesando la respuesta.

# %% [markdown]
# ## Métodos HTTP

# %% [markdown]
# Las APIs REST escuchan métodos HTTP como GET, POST y DELETE para saber qué operaciones realizar en los recursos del servicio web. Un recurso es cualquier dato disponible en el servicio web al que se puede acceder y manipular con peticiones HTTP a la API REST. El método HTTP indica a la API qué acción debe realizar sobre el recurso.
#
# Aunque hay muchos métodos HTTP, los cinco métodos que se enumeran a continuación son los más utilizados con las APIs REST:

# %% [markdown]
# <table class="table table-hover">
# <thead>
# <tr>
# <th>HTTP method</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>GET</code></td>
# <td>Retrieve an existing resource.</td>
# </tr>
# <tr>
# <td><code>POST</code></td>
# <td>Create a new resource.</td>
# </tr>
# <tr>
# <td><code>PUT</code></td>
# <td>Update an existing resource.</td>
# </tr>
# <tr>
# <td><code>PATCH</code></td>
# <td>Partially update an existing resource.</td>
# </tr>
# <tr>
# <td><code>DELETE</code></td>
# <td>Delete a resource.</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Códigos de status

# %% [markdown]
# Una vez que una API REST recibe y procesa una solicitud HTTP, devolverá una respuesta HTTP. En esta respuesta se incluye un código de estado HTTP. Este código proporciona información sobre los resultados de la solicitud. Una aplicación que envíe solicitudes a la API puede comprobar el código de estado y realizar acciones basadas en el resultado. Estas acciones pueden incluir la gestión de errores o la visualización de un mensaje de éxito a un usuario.
#
# A continuación se muestra una lista de los códigos de estado más comunes devueltos por las APIs de REST:
#
# <div class="table-responsive">
# <table class="table table-hover">
# <thead>
# <tr>
# <th>Code</th>
# <th>Meaning</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>200</code></td>
# <td>OK</td>
# <td>The requested action was successful.</td>
# </tr>
# <tr>
# <td><code>201</code></td>
# <td>Created</td>
# <td>A new resource was created.</td>
# </tr>
# <tr>
# <td><code>202</code></td>
# <td>Accepted</td>
# <td>The request was received, but no modification has been made yet.</td>
# </tr>
# <tr>
# <td><code>204</code></td>
# <td>No Content</td>
# <td>The request was successful, but the response has no content.</td>
# </tr>
# <tr>
# <td><code>400</code></td>
# <td>Bad Request</td>
# <td>The request was malformed.</td>
# </tr>
# <tr>
# <td><code>401</code></td>
# <td>Unauthorized</td>
# <td>The client is not authorized to perform the requested action.</td>
# </tr>
# <tr>
# <td><code>404</code></td>
# <td>Not Found</td>
# <td>The requested resource was not found.</td>
# </tr>
# <tr>
# <td><code>415</code></td>
# <td>Unsupported Media Type</td>
# <td>The request data format is not supported by the server.</td>
# </tr>
# <tr>
# <td><code>422</code></td>
# <td>Unprocessable Entity</td>
# <td>The request data was properly formatted but contained invalid or missing data.</td>
# </tr>
# <tr>
# <td><code>500</code></td>
# <td>Internal Server Error</td>
# <td>The server threw an error when processing the request.</td>
# </tr>
# </tbody>
# </table>
# </div>

# %% [markdown]
# ## API Endpoints

# %% [markdown]
# Una API REST expone un conjunto de URLs públicas que las aplicaciones cliente utilizan para acceder a los recursos de un servicio web. Estas URL, en el contexto de una API, se denominan `endpoints`.
#
# Para ayudar a aclarar esto, eche un vistazo a la siguiente tabla. En esta tabla, verá los puntos finales de la API para un hipotético sistema CRM. Estos endpoints son para un recurso de cliente que representa clientes potenciales en el sistema:
#
# <div class="table-responsive">
# <table class="table table-hover">
# <thead>
# <tr>
# <th>HTTP method</th>
# <th>API endpoint</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>GET</code></td>
# <td><code>/customers</code></td>
# <td>Get a list of customers.</td>
# </tr>
# <tr>
# <td><code>GET</code></td>
# <td><code>/customers/&lt;customer_id&gt;</code></td>
# <td>Get a single customer.</td>
# </tr>
# <tr>
# <td><code>POST</code></td>
# <td><code>/customers</code></td>
# <td>Create a new customer.</td>
# </tr>
# <tr>
# <td><code>PUT</code></td>
# <td><code>/customers/&lt;customer_id&gt;</code></td>
# <td>Update a customer.</td>
# </tr>
# <tr>
# <td><code>PATCH</code></td>
# <td><code>/customers/&lt;customer_id&gt;</code></td>
# <td>Partially update a customer.</td>
# </tr>
# <tr>
# <td><code>DELETE</code></td>
# <td><code>/customers/&lt;customer_id&gt;</code></td>
# <td>Delete a customer.</td>
# </tr>
# </tbody>
# </table>
# </div>

# %% [markdown]
# **Nota**: Se omite por brevedad, pero la URL completa sería del tipo `https://api.example.com/customers`

# %% [markdown]
# Observará que algunos endpoints tienen `<customer_id>` al final. Esta notación significa que debe añadir un customer_id numérico a la URL para indicar a la API REST con qué cliente desea trabajar.
#
# Los endpoints enumerados anteriormente representan sólo un recurso del sistema. Las API REST listas para la producción suelen tener decenas o incluso cientos de endpoints diferentes para gestionar los recursos del servicio web.

# %% [markdown]
# ## Consumir APIs con Python

# %% [markdown]
# Para escribir código que interactúe con las APIs REST, la mayoría de los desarrolladores de Python recurren ala librería `requests` para enviar solicitudes HTTP. Esta librería abstrae las complejidades de hacer peticiones HTTP.
#
# Para empezar a usar `requests`, necesitas instalarla primero. Puedes usar pip:

# %%
# !pip install requests

# %% [markdown]
# ### GET

# %% [markdown]
# GET es uno de los métodos HTTP más comunes que utilizará cuando trabaje con APIs REST. Este método le permite recuperar recursos de una determinada API. GET es una operación de **sólo lectura**, por lo que no debe utilizarla para modificar un recurso existente.
#
# Para probar GET y los demás métodos de esta sección, utilizarás un servicio llamado JSONPlaceholder. Este servicio gratuito proporciona puntos finales de API falsos que devuelven respuestas que las solicitudes pueden procesar.
#
# Para probarlo, inicia el REPL de Python y ejecuta los siguientes comandos para enviar una solicitud GET a un punto final de JSONPlaceholder:

# %%
import requests
api_url = "https://jsonplaceholder.typicode.com/todos/1"
response = requests.get(api_url)
response.json()
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
# Check status
response.status_code
# Out:
# 200

# %%
# probar generado un error
api_url = "https://jsonplaceholder.typicode.com/todos/1a"
response = requests.get(api_url)
response.json()
response.status_code
# Out:
# 404

# %%
# probar generado un error
api_url = "https://jsonplaceholder.typicode.com/todos/"
response = requests.get(api_url)
response.json()
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %% [markdown]
# Este código llama a `requests.get()` para enviar una petición GET a `/todos/1`, que responde con el elemento todo con el ID 1. A continuación, puede llamar a `.json()` en el objeto de respuesta para ver los datos devueltos por la API.
#
# Los datos de la respuesta están formateados como JSON, un almacén de clave-valor similar a un diccionario de Python. Es un formato de datos muy popular y el formato de intercambio de facto para la mayoría de las APIs REST.
#
# Además de ver los datos JSON de la API, también puede ver otras cosas sobre la respuesta:

# %%
print(response.status_code)
print(response.headers["Content-Type"])
print(response.headers)
# Out:
# 200
# application/json; charset=utf-8
# {'Date': 'Mon, 08 Jul 2024 18:36:16 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Report-To': '{"group":"heroku-nel","max_age":3600,"endpoints":[{"url":"https://nel.heroku.com/reports?ts=1720463776&sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d&s=eGcZoInnAMRLfeBrIPSk0E3EjDVKZGGQLLceotjTKZ4%3D"}]}', 'Reporting-Endpoints': 'heroku-nel=https://nel.heroku.com/reports?ts=1720463776&sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d&s=eGcZoInnAMRLfeBrIPSk0E3EjDVKZGGQLLceotjTKZ4%3D', 'Nel': '{"report_to":"heroku-nel","max_age":3600,"success_fraction":0.005,"failure_fraction":0.05,"response_headers":["Via"]}', 'X-Powered-By': 'Express', 'X-Ratelimit-Limit': '1000', 'X-Ratelimit-Remaining': '989', 'X-Ratelimit-Reset': '1720463786', 'Vary': 'Origin, Accept-Encoding', 'Access-Control-Allow-Credentials': 'true', 'Cache-Control': 'max-age=43200', 'Pragma': 'no-cache', 'Expires': '-1', 'X-Content-Type-Options': 'nosniff', 'Etag': 'W/"5ef7-4Ad6/n39KWY9q6Ykm/ULNQ2F5IM"', 'Content-Encoding': 'gzip', 'Via': '1.1 vegur', 'CF-Cache-Status': 'MISS', 'Server': 'cloudflare', 'CF-RAY': '8a022dc73c4e0402-MAD', 'alt-svc': 'h3=":443"; ma=86400'}

# %% [markdown]
# Aquí se accede a `response.status_code` para ver el código de estado HTTP. También puedes ver las cabeceras HTTP de la respuesta con `response.headers`. Este diccionario contiene metadatos sobre la respuesta, como el Content-Type de la respuesta.

# %% [markdown]
# ### POST

# %% [markdown]
# Aquí se llama a `requests.post()` para crear una nueva tarea en el sistema.
#
# 1. Se crea un diccionario que contiene los datos de la tarea
# 2. Pasa este diccionario al argumento de la palabra clave json de `requests.post()`
# 3. Al hacer esto, requests.post() automáticamente establece el encabezado HTTP Content-Type de la solicitud a application/json. También serializa todo en una cadena JSON, que añade al cuerpo de la petición.

# %%
api_url = "https://jsonplaceholder.typicode.com/todos"
todo = {"userId": 1, "title": "Buy milk", "completed": 333, 'prueba':12}
response = requests.post(api_url, json=todo)
print(response.json())
print(response.status_code)
# Out:
# {'userId': 1, 'title': 'Buy milk', 'completed': 333, 'prueba': 12, 'id': 201}
# 201

# %% [markdown]
# Si no utiliza el argumento `json` en la función para suministrar los datos JSON, deberá establecer el `Content-Type` correspondiente y serializar el JSON manualmente. Aquí hay una versión equivalente al código anterior:

# %%
import json
api_url = "https://jsonplaceholder.typicode.com/todos"
todo = {"userId": 1, "title": "Buy milk", "completed": False}
headers =  {"Content-Type":"application/json"}
response = requests.post(api_url, data=json.dumps(todo), headers=headers)

print(response.json())
print(response.status_code)
# Out:
# {'userId': 1, 'title': 'Buy milk', 'completed': False, 'id': 201}
# 201

# %%
import pandas as pd
dt = pd.DataFrame([[1,"Buy milk", False], [1, 'Buy potatoes', True]], columns=["userId", "title", "completed"])
dt
# Out:
#    userId         title  completed
# 0       1      Buy milk      False
# 1       1  Buy potatoes       True

# %%
# To json
dt.to_json(orient='records')
# Out:
# '[{"userId":1,"title":"Buy milk","completed":false},{"userId":1,"title":"Buy potatoes","completed":true}]'

# %%
# To json
dt.to_json()
# Out:
# '{"userId":{"0":1,"1":1},"title":{"0":"Buy milk","1":"Buy potatoes"},"completed":{"0":false,"1":true}}'

# %%
# Completar
headers =  {"Content-Type":"application/json"}
response = requests.post(api_url, data=dt.to_json(), headers=headers)

print(response.json())
print(response.status_code)
# Out:
# {'userId': {'0': 1, '1': 1}, 'title': {'0': 'Buy milk', '1': 'Buy potatoes'}, 'completed': {'0': False, '1': True}, 'id': 201}
# 201

# %% [markdown]
# ### PUT

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
response = requests.get(api_url)
print(response.json())
# Out:
# {'userId': 1, 'id': 10, 'title': 'illo est ratione doloremque quia maiores aut', 'completed': True}

# %%
todo = {"userId": 1, "title": "Wash car", "completed": True}
response = requests.put(api_url, json=todo)
print(response.json())
print(response.status_code)
# Out:
# {'userId': 1, 'title': 'Wash car', 'completed': True, 'id': 10}
# 200

# %% [markdown]
# ### PATCH

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
todo = {"title": "Mow lawn"}
response = requests.patch(api_url, json=todo)
print(response.json())
print(response.status_code)
# Out:
# {'userId': 1, 'id': 10, 'title': 'Mow lawn', 'completed': True}
# 200

# %% [markdown]
# ### DELETE

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
response = requests.delete(api_url)
response.json()
# Out:
# {}

# %% [markdown]
# ## Ejemplo: Datos Sevici

# %% [markdown]
# Hoy en día, una gran cantidad de sitios web facilitan acceso a sus datos a través de API RESTs. Un ejemplo es la siguiente web con información geográfica sobre distintos aspectos de nuestra ciudad.

# %%
# En la web encontramos la especificación de la API que nos interesa
url = 'https://services1.arcgis.com/hcmP7kr0Cx3AcTJk/arcgis/rest/services/Estaciones_Sevici/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'
r = requests.get(url)

# Escribimos el json para poder pasarlo por un Beautifier (https://codebeautify.org/jsonviewer) 
# que nos permite visualizarlo de manera sencilla
with open("sevici.json", "w") as f:
    json.dump(r.json(), f)

# %% [markdown]
# El formato de los datos no es muy amigable pero con un poco de exploración encontramos la información que nos interesa

# %%
# Guardamos la respuesta en un diccionario
raw_data = r.json()

# %%
print(raw_data)
# Out:
# {'objectIdFieldName': 'FID', 'uniqueIdField': {'name': 'FID', 'isSystemMaintained': True}, 'globalIdFieldName': '', 'geometryType': 'esriGeometryPoint', 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'fields': [{'name': 'FID', 'type': 'esriFieldTypeInteger', 'alias': 'FID', 'sqlType': 'sqlTypeInteger', 'domain': None, 'defaultValue': None}, {'name': 'id_estacio', 'type': 'esriFieldTypeDouble', 'alias': 'id_estacio', 'sqlType': 'sqlTypeFloat', 'domain': None, 'defaultValue': None}, {'name': 'Direccion', 'type': 'esriFieldTypeString', 'alias': 'Direccion', 'sqlType': 'sqlTypeNVarchar', 'length': 254, 'domain': None, 'defaultValue': None}, {'name': 'Aproximaci', 'type': 'esriFieldTypeString', 'alias': 'Aproximaci', 'sqlType': 'sqlTypeNVarchar', 'length': 254, 'domain': None, 'defaultValue': None}, {'name': 'Lat_Y', 'type': 'esriFieldTypeDouble', 'alias': 'Lat_Y', 'sqlType': 'sqlTypeFloat', 'domain': None, 'defaultValue': None}, {'name': 'Lon_X', 'type': 'esriFieldTypeDouble', 'alias': 'Lon_X', 'sqlType': 'sqlTypeFloat', 'domain': None, 'defaultValue': None}, {'name': 'CreationDate', 'type': 'esriFieldTypeDate', 'alias': 'CreationDate', 'sqlType': 'sqlTypeOther', 'length': 8, 'domain': None, 'defaultValue': None}, {'name': 'Creator', 'type': 'esriFieldTypeString', 'alias': 'Creator', 'sqlType': 'sqlTypeOther', 'length': 50, 'domain': None, 'defaultValue': None}, {'name': 'EditDate', 'type': 'esriFieldTypeDate', 'alias': 'EditDate', 'sqlType': 'sqlTypeOther', 'length': 8, 'domain': None, 'defaultValue': None}, {'name': 'Editor', 'type': 'esriFieldTypeString', 'alias': 'Editor', 'sqlType': 'sqlTypeOther', 'length': 50, 'domain': None, 'defaultValue': None}], 'features': [{'attributes': {'FID': 1, 'id_estacio': 1, 'Direccion': 'Glorieta Olimpica', 'Aproximaci': 'Concejal Alberto Jiménez-Becerril', 'Lat_Y': 37.412983, 'Lon_X': -5.988933, 'CreationDate': 1412457692379, 'Creator': 'Ayto.Sevilla', 'EditDate': 1412457692379, 'Editor': 'Ayto.Sevilla'}, 'geometry': {'x': -5.988933251932231, 'y': 37.412983041853934}}, {'attributes': {'FID': 2, 'id_estacio': 2, 'Direccion': 'Gran Plaza', 'Aproximaci': 'Calle Marquez de Pickman', 'Lat_Y': 37.381664, 'Lon_X': -5.965183, 'CreationDate': 1412457692379, 'Creator': 'Ayto.Sevilla', 'EditDate': 1412457692379, 'Editor': 'Ayto.Sevilla'}, 'geometry': {'x': -5.965182694135409, 'y': 37.381664061223965}}, {'attributes': {'FID': 3, 'id_estacio': 3, 'Direccion': 'Puerta de la Barqueta', 'Aproximaci': 'Puente de la Barqueta', 'Lat_Y': 37.40564, 'Lon_X': -5.998514, 'CreationDate': 1412457692379, 'Creator': 'Ayto.Sevilla', 'EditDate': 1412457692379, 'Editor': 'Ayto.Sevilla'}, 'geometry': {'x': -5.998513784437367, 'y': 37.40563993879666}}, {'attributes': {'FID': 4, 'id_estacio': 4, 'Direccion': 'Calle Leonardo Da Vinci', 'Aproximaci': 'Calle Thomas Alba Edison', 'Lat_Y': 37.410126, 'Lon_X': -6.005659, 'CreationDate': 1412457692379, 'Creator': 'Ayto.Sevilla', 'EditDate': 1412457692379, 'Editor': 'Ayto.Sevilla'}, 'geometry': {'x': -6.00565898420724, 'y': 37.41012608875761}}, {'attributes': {'FID': 5, 'id_estacio': 131, 'Direccion': 'Calle Tabladilla', 'Aproximaci': 'Calle Cardenal Ilundaín', 'Lat_Y': 37.364746, 'Lon_X': -5.981396, 'CreationDate': 1412457692379, 'Creator': 'Ayto.Sevilla', 'EditDate': 1412457692379, 'Editor': 'Ayto.Sevilla'}, 'geometry': {'x': -5.981396386698469, 'y': 37.36474629901322}}, {'attributes': {'FID': 6, 'id_estacio': 132, 'Direccion': 'Calle Paez de Ribera', 'Aproximaci': 'Paseo de la Palmera', 'Lat_Y': 37.36367, 'Lon_X': -5.984777, 'CreationDate': 1412457692379, 'Creator': 'Ayto.Sevilla', 'EditDate': 1412457692379, 'Editor': 'Ayto.Sevilla'}, 'geometry': {'x': -5.984776747112617, 'y': 37.36367033794603}}, {'attributes': {'FID': 7, 'id_estacio': 5, 'Direccion': 'Camino de los Descubrimientos', 'Aproximaci': 'Calle Thomás Alba Edison', 'Lat_Y': 37.411022, 'Lon_X': -6.001936, 'CreationDate': 1412457692379, 'Creator': 'Ayto.Sevilla', 'EditDate': 1412457692379, 'Editor': 'Ayto.Sevilla ...

# %%
import pprint
pprint.pprint(raw_data)
# Out:
# {'features': [{'attributes': {'Aproximaci': 'Concejal Alberto Jiménez-Becerril',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Glorieta Olimpica',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 1,
#                               'Lat_Y': 37.412983,
#                               'Lon_X': -5.988933,
#                               'id_estacio': 1},
#                'geometry': {'x': -5.988933251932231, 'y': 37.412983041853934}},
#               {'attributes': {'Aproximaci': 'Calle Marquez de Pickman',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Gran Plaza',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 2,
#                               'Lat_Y': 37.381664,
#                               'Lon_X': -5.965183,
#                               'id_estacio': 2},
#                'geometry': {'x': -5.965182694135409, 'y': 37.381664061223965}},
#               {'attributes': {'Aproximaci': 'Puente de la Barqueta',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Puerta de la Barqueta',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 3,
#                               'Lat_Y': 37.40564,
#                               'Lon_X': -5.998514,
#                               'id_estacio': 3},
#                'geometry': {'x': -5.998513784437367, 'y': 37.40563993879666}},
#               {'attributes': {'Aproximaci': 'Calle Thomas Alba Edison',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Leonardo Da Vinci',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 4,
#                               'Lat_Y': 37.410126,
#                               'Lon_X': -6.005659,
#                               'id_estacio': 4},
#                'geometry': {'x': -6.00565898420724, 'y': 37.41012608875761}},
#               {'attributes': {'Aproximaci': 'Calle Cardenal Ilundaín',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Tabladilla',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 5,
#                               'Lat_Y': 37.364746,
#                               'Lon_X': -5.981396,
#                               'id_estacio': 131},
#                'geometry': {'x': -5.981396386698469, 'y': 37.36474629901322}},
#               {'attributes': {'Aproximaci': 'Paseo de la Palmera',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Paez de Ribera',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 6,
#                               'Lat_Y': 37.36367,
#                               'Lon_X': -5.984777,
#                               'id_estacio': 132},
#                'geometry': {'x': -5.984776747112617, 'y': 37.36367033794603}},
#               {'attributes': {'Aproximaci': 'Calle Thomás Alba Edison',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Camino de los Descubrimientos',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 7,
#                               'Lat_Y': 37.411022,
#                               'Lon_X': -6.001936,
#                               'id_estacio': 5},
#                'geometry': {'x': -6.001936365669861, 'y': 37.41102228757182}},
#               {'attributes': {'Aproximaci': 'Calle Virgen de la Oliva',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Santa Fe',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 8,
#                               'Lat_Y': 37.374001,
#                               'Lon_X': -6.004259,
#                               'id_estacio': 133},
#                'geometry': {'x': -6.004259408994608, 'y': 37.374000926161294}},
#               {'attributes': {'Aproximaci': 'Calle Isaac Newton',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Camino de los Descubrimientos',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 9,
#                               'Lat_Y': 37.406677,
#                               'Lon_X': -6.002848,
#                               'id_estacio': 6},
#                'geometry': {'x': -6.002848155683243, 'y': 37.40667676493793}},
#               {'attributes': {'Aproximaci': 'Calle Asunción',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Virgen de Luján',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 10,
#                               'Lat_Y': 37.374783,
#                               'Lon_X': -5.998519,
#                               'id_estacio': 134},
#                'geometry': {'x': -5.998519174329084, 'y': 37.37478333708746}},
#               {'attributes': {'Aproximaci': 'Calle de Jacques Cousteau',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Américo Vespucio',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 11,
#                               'Lat_Y': 37.407516,
#                               'Lon_X': -6.007413,
#                               'id_estacio': 7},
#                'geometry': {'x': -6.0074133939571315, 'y': 37.40751591998063}},
#               {'attributes': {'Aproximaci': 'Glorieta las Cigarreras',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Virgen de Luján',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 12,
#                               'Lat_Y': 37.374657,
#                               'Lon_X': -5.994916,
#                               'id_estacio': 135},
#                'geometry': {'x': -5.994916031724467, 'y': 37.374656981131004}},
#               {'attributes': {'Aproximaci': 'Calle Virgen de la Antigua',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Asunción',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 13,
#                               'Lat_Y': 37.373226,
#                               'Lon_X': -5.99763,
#                               'id_estacio': 136},
#                'geometry': {'x': -5.9976298421978065, 'y': 37.37322564597106}},
#               {'attributes': {'Aproximaci': 'Calle Gregor Mendel',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Leonardo Da Vinci',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 14,
#                               'Lat_Y': 37.401035,
#                               'Lon_X': -6.009403,
#                               'id_estacio': 8},
#                'geometry': {'x': -6.0094031623114565, 'y': 37.401035058562336}},
#               {'attributes': {'Aproximaci': 'Calle Porvenir',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de la Borbolla',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 15,
#                               'Lat_Y': 37.373745,
#                               'Lon_X': -5.985478,
#                               'id_estacio': 137},
#                'geometry': {'x': -5.985478331349495, 'y': 37.37374535586052}},
#               {'attributes': {'Aproximaci': 'Calle San Salvador',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Ramón Carande',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 16,
#                               'Lat_Y': 37.375852,
#                               'Lon_X': -5.978978,
#                               'id_estacio': 138},
#                'geometry': {'x': -5.9789781219536255, 'y': 37.37585271400338}},
#               {'attributes': {'Aproximaci': 'Calle Albert Einstein',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Camino de los Descubrimientos',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 17,
#                               'Lat_Y': 37.402927,
#                               'Lon_X': -6.004066,
#                               'id_estacio': 9},
#                'geometry': {'x': -6.004066271208522, 'y': 37.40292685439503}},
#               {'attributes': {'Aproximaci': 'Avenida General García de la '
#                                             'Herranz',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Diego Martinez Barrio',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 18,
#                               'Lat_Y': 37.37516,
#                               'Lon_X': -5.975825,
#                               'id_estacio': 139},
#                'geometry': {'x': -5.975825035306366, 'y': 37.37516026206606}},
#               {'attributes': {'Aproximaci': 'Avenida Concejal Alberto '
#                                             'Jiménez-Becerril',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle José Diaz',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 19,
#                               'Lat_Y': 37.409096,
#                               'Lon_X': -5.990961,
#                               'id_estacio': 10},
#                'geometry': {'x': -5.990960749528482, 'y': 37.409095732285955}},
#               {'attributes': {'Aproximaci': 'Avenida Diego Martínez Barrio',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Felipe II',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 20,
#                               'Lat_Y': 37.372375,
#                               'Lon_X': -5.977351,
#                               'id_estacio': 140},
#                'geometry': {'x': -5.977351272974071, 'y': 37.37237468464117}},
#               {'attributes': {'Aproximaci': 'Calle Avenzoar',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Avicena',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 21,
#                               'Lat_Y': 37.405846,
#                               'Lon_X': -5.993214,
#                               'id_estacio': 11},
#                'geometry': {'x': -5.993213724261061, 'y': 37.40584616344617}},
#               {'attributes': {'Aproximaci': 'Calle Ramón Carande',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Felipe II',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 22,
#                               'Lat_Y': 37.371716,
#                               'Lon_X': -5.9819,
#                               'id_estacio': 141},
#                'geometry': {'x': -5.981900341572873, 'y': 37.37171575409409}},
#               {'attributes': {'Aproximaci': 'Barqueta',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Plaza Duquesa de Alba',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 23,
#                               'Lat_Y': 37.403854,
#                               'Lon_X': -5.99493,
#                               'id_estacio': 12},
#                'geometry': {'x': -5.994930404769027, 'y': 37.403853824053996}},
#               {'attributes': {'Aproximaci': 'Calle Asunción',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Ramon de Carranza',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 24,
#                               'Lat_Y': 37.371639,
#                               'Lon_X': -5.997197,
#                               'id_estacio': 142},
#                'geometry': {'x': -5.997196854230833, 'y': 37.37163865241669}},
#               {'attributes': {'Aproximaci': 'Calle Resolana',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Feria',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 25,
#                               'Lat_Y': 37.403156,
#                               'Lon_X': -5.991856,
#                               'id_estacio': 13},
#                'geometry': {'x': -5.991856369866744, 'y': 37.40315592186714}},
#               {'attributes': {'Aproximaci': 'Calle Virgen de la Oliva',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Ramon de Carranza',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 26,
#                               'Lat_Y': 37.371628,
#                               'Lon_X': -6.003318,
#                               'id_estacio': 143},
#                'geometry': {'x': -6.003317974576844, 'y': 37.371627943844125}},
#               {'attributes': {'Aproximaci': 'Clinica de Fátima',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de la Palmera',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 27,
#                               'Lat_Y': 37.369106,
#                               'Lon_X': -5.988002,
#                               'id_estacio': 144},
#                'geometry': {'x': -5.988001698982607, 'y': 37.36910567547082}},
#               {'attributes': {'Aproximaci': 'Facultad de medicina',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Sánchez Pizjuan',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 28,
#                               'Lat_Y': 37.406918,
#                               'Lon_X': -5.989079,
#                               'id_estacio': 14},
#                'geometry': {'x': -5.989078779008253, 'y': 37.4069179516185}},
#               {'attributes': {'Aproximaci': 'Calle Profesor García González',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Reina Mercedes',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 29,
#                               'Lat_Y': 37.360226,
#                               'Lon_X': -5.986358,
#                               'id_estacio': 145},
#                'geometry': {'x': -5.986357782012667, 'y': 37.36022601643254}},
#               {'attributes': {'Aproximaci': 'Calle San Juan de Ribera',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Dr Marañon',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 30,
#                               'Lat_Y': 37.407227,
#                               'Lon_X': -5.985341,
#                               'id_estacio': 15},
#                'geometry': {'x': -5.98534088911105, 'y': 37.40722692632038}},
#               {'attributes': {'Aproximaci': 'Calle Profesor García González',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Reina Mercedes',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 31,
#                               'Lat_Y': 37.360119,
#                               'Lon_X': -5.986358,
#                               'id_estacio': 146},
#                'geometry': {'x': -5.986357782012667, 'y': 37.36011891434875}},
#               {'attributes': {'Aproximaci': 'Calle Sor Francisca Dorotea',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Manuel Villalobos',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 32,
#                               'Lat_Y': 37.407028,
#                               'Lon_X': -5.982795,
#                               'id_estacio': 16},
#                'geometry': {'x': -5.9827950635958365, 'y': 37.407027841150395}},
#               {'attributes': {'Aproximaci': 'Calle Maestro Solano',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Carretera de Carmona',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 33,
#                               'Lat_Y': 37.400829,
#                               'Lon_X': -5.975233,
#                               'id_estacio': 147},
#                'geometry': {'x': -5.975233045534112, 'y': 37.40082882067124}},
#               {'attributes': {'Aproximaci': 'Ronda de Pio XII',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle de Madreselva',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 34,
#                               'Lat_Y': 37.407173,
#                               'Lon_X': -5.978907,
#                               'id_estacio': 17},
#                'geometry': {'x': -5.97890715504616, 'y': 37.40717269528706}},
#               {'attributes': {'Aproximaci': 'Calle Marqués del Nervión',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Eduardo Dato',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 35,
#                               'Lat_Y': 37.382,
#                               'Lon_X': -5.96814,
#                               'id_estacio': 18},
#                'geometry': {'x': -5.968139948050724, 'y': 37.38200026468263}},
#               {'attributes': {'Aproximaci': 'Calle Aorno',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Tharsis',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 36,
#                               'Lat_Y': 37.398758,
#                               'Lon_X': -5.97321,
#                               'id_estacio': 148},
#                'geometry': {'x': -5.9732100395142815, 'y': 37.398757846783575}},
#               {'attributes': {'Aproximaci': 'Calle Don Fadrique',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Parlamento',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 37,
#                               'Lat_Y': 37.40324,
#                               'Lon_X': -5.988962,
#                               'id_estacio': 19},
#                'geometry': {'x': -5.988961998021317, 'y': 37.40324012717928}},
#               {'attributes': {'Aproximaci': 'Calle Tena',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Arroyo',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 38,
#                               'Lat_Y': 37.397854,
#                               'Lon_X': -5.975711,
#                               'id_estacio': 149},
#                'geometry': {'x': -5.97571094926529, 'y': 37.39785365105625}},
#               {'attributes': {'Aproximaci': 'Calle Arroyo',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle San Juan Bosco',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 39,
#                               'Lat_Y': 37.396782,
#                               'Lon_X': -5.978621,
#                               'id_estacio': 150},
#                'geometry': {'x': -5.97862059247054, 'y': 37.3967817332289}},
#               {'attributes': {'Aproximaci': 'Calle Fray Isidoro de Sevilla',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle San Juan de Ribera',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 40,
#                               'Lat_Y': 37.404736,
#                               'Lon_X': -5.986699,
#                               'id_estacio': 20},
#                'geometry': {'x': -5.986699141820633, 'y': 37.404735826108066}},
#               {'attributes': {'Aproximaci': 'Esquina calle Venecia',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Urquiza',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 41,
#                               'Lat_Y': 37.394619,
#                               'Lon_X': -5.979927,
#                               'id_estacio': 151},
#                'geometry': {'x': -5.979926742893635, 'y': 37.3946192957473}},
#               {'attributes': {'Aproximaci': 'Calle Esperanza de la Trinidad',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Samaniego',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 42,
#                               'Lat_Y': 37.395821,
#                               'Lon_X': -5.974481,
#                               'id_estacio': 152},
#                'geometry': {'x': -5.9744811556413095, 'y': 37.39582113338918}},
#               {'attributes': {'Aproximaci': 'Calle Madre San Marcelo',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Manuel Villalobos',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 43,
#                               'Lat_Y': 37.405506,
#                               'Lon_X': -5.981498,
#                               'id_estacio': 21},
#                'geometry': {'x': -5.981497896325581, 'y': 37.4055057854327}},
#               {'attributes': {'Aproximaci': 'Avenida de Miraflores',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de Llanes',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 44,
#                               'Lat_Y': 37.405144,
#                               'Lon_X': -5.974867,
#                               'id_estacio': 22},
#                'geometry': {'x': -5.9748674312134815, 'y': 37.40514399830178}},
#               {'attributes': {'Aproximaci': 'Escuela de Arquitectura',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Reina Mercedes',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 45,
#                               'Lat_Y': 37.362988,
#                               'Lon_X': -5.986259,
#                               'id_estacio': 153},
#                'geometry': {'x': -5.986258967331414, 'y': 37.362987769377156}},
#               {'attributes': {'Aproximaci': 'Calle San Juan de Ribera',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Parlamento',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 46,
#                               'Lat_Y': 37.403358,
#                               'Lon_X': -5.987928,
#                               'id_estacio': 23},
#                'geometry': {'x': -5.987928037129315, 'y': 37.403357871736766}},
#               {'attributes': {'Aproximaci': 'Calle Naranjito de Triana',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Kansas City',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 47,
#                               'Lat_Y': 37.394875,
#                               'Lon_X': -5.968394,
#                               'id_estacio': 154},
#                'geometry': {'x': -5.968394171276136, 'y': 37.3948747949112}},
#               {'attributes': {'Aproximaci': 'Calle Fray Isidoro de Sevilla',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle León XIII',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 48,
#                               'Lat_Y': 37.404034,
#                               'Lon_X': -5.984668,
#                               'id_estacio': 24},
#                'geometry': {'x': -5.984668050963226, 'y': 37.40403365055813}},
#               {'attributes': {'Aproximaci': 'Avenida El Greco',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Kansas City',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 49,
#                               'Lat_Y': 37.392906,
#                               'Lon_X': -5.970766,
#                               'id_estacio': 155},
#                'geometry': {'x': -5.9707657236262115, 'y': 37.39290571599825}},
#               {'attributes': {'Aproximaci': 'Calle Albaida',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de la Cruz Roja',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 50,
#                               'Lat_Y': 37.403145,
#                               'Lon_X': -5.981085,
#                               'id_estacio': 25},
#                'geometry': {'x': -5.981084671294886, 'y': 37.40314521779525}},
#               {'attributes': {'Aproximaci': 'Baltasar Gracián',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Kansas City',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 51,
#                               'Lat_Y': 37.391483,
#                               'Lon_X': -5.972649,
#                               'id_estacio': 156},
#                'geometry': {'x': -5.972648592461707, 'y': 37.39148329372427}},
#               {'attributes': {'Aproximaci': 'Calle Manuel Ródenas',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de Miraflores',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 52,
#                               'Lat_Y': 37.402542,
#                               'Lon_X': -5.977635,
#                               'id_estacio': 26},
#                'geometry': {'x': -5.9776351406038675, 'y': 37.402542219276434}},
#               {'attributes': {'Aproximaci': 'Avenida Ramón Carande',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Cardenal Bueno Monreal',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 53,
#                               'Lat_Y': 37.369778,
#                               'Lon_X': -5.978165,
#                               'id_estacio': 157},
#                'geometry': {'x': -5.978165146621497, 'y': 37.36977819347244}},
#               {'attributes': {'Aproximaci': 'Calle Escultor Francisco Buiza',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de Llanes',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 54,
#                               'Lat_Y': 37.403881,
#                               'Lon_X': -5.972099,
#                               'id_estacio': 27},
#                'geometry': {'x': -5.972098823507832, 'y': 37.40388094077673}},
#               {'attributes': {'Aproximaci': 'Calle Castillo Alcala de Guadaira',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Rafael Salgado',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 55,
#                               'Lat_Y': 37.360332,
#                               'Lon_X': -5.976723,
#                               'id_estacio': 28},
#                'geometry': {'x': -5.976723350590486, 'y': 37.36033169033877}},
#               {'attributes': {'Aproximaci': 'Calle Bogota',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Cardenal Bueno Monreal',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 56,
#                               'Lat_Y': 37.368866,
#                               'Lon_X': -5.981573,
#                               'id_estacio': 158},
#                'geometry': {'x': -5.981573354809433, 'y': 37.36886579497975}},
#               {'attributes': {'Aproximaci': 'Avenida de Llanes',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Carretera de Carmona',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 57,
#                               'Lat_Y': 37.402534,
#                               'Lon_X': -5.970082,
#                               'id_estacio': 29},
#                'geometry': {'x': -5.970082105694983, 'y': 37.40253365594889}},
#               {'attributes': {'Aproximaci': 'Avenida Manuel Siurot',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Cardenal Bueno Monreal',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 58,
#                               'Lat_Y': 37.368046,
#                               'Lon_X': -5.984859,
#                               'id_estacio': 159},
#                'geometry': {'x': -5.98485939211875, 'y': 37.36804619751489}},
#               {'attributes': {'Aproximaci': 'Detrás Estadio Sánchez Pizjuan',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Eduardo Dato',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 59,
#                               'Lat_Y': 37.382519,
#                               'Lon_X': -5.970812,
#                               'id_estacio': 30},
#                'geometry': {'x': -5.970812436020979, 'y': 37.38251919997108}},
#               {'attributes': {'Aproximaci': 'Puente de Triana',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Arjona',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 60,
#                               'Lat_Y': 37.387516,
#                               'Lon_X': -6.001927,
#                               'id_estacio': 160},
#                'geometry': {'x': -6.001927382517021, 'y': 37.38751635584983}},
#               {'attributes': {'Aproximaci': 'Calle Albaida',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de Miraflores',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 61,
#                               'Lat_Y': 37.400414,
#                               'Lon_X': -5.979831,
#                               'id_estacio': 31},
#                'geometry': {'x': -5.979830623158241, 'y': 37.40041420229369}},
#               {'attributes': {'Aproximaci': 'Calle Baltasar de Alcázar',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Alcalde Manuel del Valle',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 62,
#                               'Lat_Y': 37.399986,
#                               'Lon_X': -5.969145,
#                               'id_estacio': 161},
#                'geometry': {'x': -5.96914516285364, 'y': 37.39998602255974}},
#               {'attributes': {'Aproximaci': 'Calle Morera',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Muñoz León',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 63,
#                               'Lat_Y': 37.402061,
#                               'Lon_X': -5.986304,
#                               'id_estacio': 32},
#                'geometry': {'x': -5.98630388309562, 'y': 37.40206124419797}},
#               {'attributes': {'Aproximaci': 'Calle Media Granaína',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Solea',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 64,
#                               'Lat_Y': 37.391525,
#                               'Lon_X': -5.968482,
#                               'id_estacio': 162},
#                'geometry': {'x': -5.968482206173953, 'y': 37.39152468923451}},
#               {'attributes': {'Aproximaci': 'Calle Antonio Pantión',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle León XIII',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 65,
#                               'Lat_Y': 37.401531,
#                               'Lon_X': -5.983708,
#                               'id_estacio': 33},
#                'geometry': {'x': -5.983707751924515, 'y': 37.401531026253515}},
#               {'attributes': {'Aproximaci': 'Calle San Luis',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Plaza Pumarejo',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 66,
#                               'Lat_Y': 37.400932,
#                               'Lon_X': -5.988557,
#                               'id_estacio': 34},
#                'geometry': {'x': -5.988556857828199, 'y': 37.40093229650069}},
#               {'attributes': {'Aproximaci': 'Calle Baltazar Gracián',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Sinaí',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 67,
#                               'Lat_Y': 37.389927,
#                               'Lon_X': -5.970793,
#                               'id_estacio': 163},
#                'geometry': {'x': -5.970792673084735, 'y': 37.38992666320577}},
#               {'attributes': {'Aproximaci': 'Calle Peris Mencheta',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Alameda de Hercules',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 68,
#                               'Lat_Y': 37.400818,
#                               'Lon_X': -5.993774,
#                               'id_estacio': 35},
#                'geometry': {'x': -5.993774272998339, 'y': 37.40081811626693}},
#               {'attributes': {'Aproximaci': 'Calle Guadalquivir',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle San Vicente',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 69,
#                               'Lat_Y': 37.400543,
#                               'Lon_X': -5.998318,
#                               'id_estacio': 36},
#                'geometry': {'x': -5.998317951705421, 'y': 37.40054265573681}},
#               {'attributes': {'Aproximaci': 'Calle El Greco',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Luis Montoto',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 70,
#                               'Lat_Y': 37.387638,
#                               'Lon_X': -5.965657,
#                               'id_estacio': 164},
#                'geometry': {'x': -5.965657004605397, 'y': 37.387637693873444}},
#               {'attributes': {'Aproximaci': 'Centro Comercial Los Arcos',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de Andalucia',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 71,
#                               'Lat_Y': 37.387638,
#                               'Lon_X': -5.961011,
#                               'id_estacio': 165},
#                'geometry': {'x': -5.961010917955938, 'y': 37.387637693873444}},
#               {'attributes': {'Aproximaci': 'Calle Vulcano',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Alameda de Hércules',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 72,
#                               'Lat_Y': 37.398609,
#                               'Lon_X': -5.99357,
#                               'id_estacio': 37},
#                'geometry': {'x': -5.99357035542885, 'y': 37.39860869449067}},
#               {'attributes': {'Aproximaci': 'Centro Comercial Los Arcos',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Ronda del Tamarguillo',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 73,
#                               'Lat_Y': 37.388538,
#                               'Lon_X': -5.959222,
#                               'id_estacio': 166},
#                'geometry': {'x': -5.959222372225276, 'y': 37.38853773037659}},
#               {'attributes': {'Aproximaci': 'Calle Juan Antonio de Vizarrón',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle del Inca Garcilaso',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 74,
#                               'Lat_Y': 37.392025,
#                               'Lon_X': -6.011066,
#                               'id_estacio': 38},
#                'geometry': {'x': -6.011065943902375, 'y': 37.39202500212775}},
#               {'attributes': {'Aproximaci': 'Ramón y Cajal, Esq. Ronda',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Glorieta Bizco Amate',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 75,
#                               'Lat_Y': 37.373352,
#                               'Lon_X': -5.964932,
#                               'id_estacio': 167},
#                'geometry': {'x': -5.964932064171119, 'y': 37.37335200433865}},
#               {'attributes': {'Aproximaci': 'Avenida de la Ciudad Jardín',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
# ...
#               {'attributes': {'Aproximaci': 'Cueva de la Pileta',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Alcalde Luis Uruñuela',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 240,
#                               'Lat_Y': 37.402603,
#                               'Lon_X': -5.94051,
#                               'id_estacio': 240},
#                'geometry': {'x': -5.940509566541769, 'y': 37.40260287615168}},
#               {'attributes': {'Aproximaci': 'Calle Mendez Núñez',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Plaza Nueva',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 241,
#                               'Lat_Y': 37.388844,
#                               'Lon_X': -5.996077,
#                               'id_estacio': 241},
#                'geometry': {'x': -5.996076655071543, 'y': 37.38884392589895}},
#               {'attributes': {'Aproximaci': 'Calle Mendez Núñez',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Plaza Nueva',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 242,
#                               'Lat_Y': 37.388882,
#                               'Lon_X': -5.996081,
#                               'id_estacio': 242},
#                'geometry': {'x': -5.996081146647963, 'y': 37.388881754163386}},
#               {'attributes': {'Aproximaci': 'Calle Carlos Marx',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Glorieta del Primero de Mayo',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 243,
#                               'Lat_Y': 37.380432,
#                               'Lon_X': -5.953475,
#                               'id_estacio': 243},
#                'geometry': {'x': -5.953474951037473, 'y': 37.38043201613387}},
#               {'attributes': {'Aproximaci': 'Av. de la Montería',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Juan XXIII',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 244,
#                               'Lat_Y': 37.378025,
#                               'Lon_X': -5.951685,
#                               'id_estacio': 244},
#                'geometry': {'x': -5.951684608676215, 'y': 37.37802497277194}},
#               {'attributes': {'Aproximaci': 'Calle Leandras',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle de los Gavilanes',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 245,
#                               'Lat_Y': 37.375389,
#                               'Lon_X': -5.952626,
#                               'id_estacio': 245},
#                'geometry': {'x': -5.9526260430939795, 'y': 37.37538870052517}},
#               {'attributes': {'Aproximaci': 'Calle Paulo Orosio',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Puerto de los Azores',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 246,
#                               'Lat_Y': 37.376152,
#                               'Lon_X': -5.955172,
#                               'id_estacio': 246},
#                'geometry': {'x': -5.955171868609161, 'y': 37.37615182270847}},
#               {'attributes': {'Aproximaci': 'Apeadero de San Bernardo',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Enramadilla',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 247,
#                               'Lat_Y': 37.378418,
#                               'Lon_X': -5.979398,
#                               'id_estacio': 247},
#                'geometry': {'x': -5.979397635191303, 'y': 37.378418299788066}},
#               {'attributes': {'Aproximaci': 'Calle Navarra',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Glorieta de los Ferroviarios',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 248,
#                               'Lat_Y': 37.422062,
#                               'Lon_X': -5.982863,
#                               'id_estacio': 248},
#                'geometry': {'x': -5.982863335557442, 'y': 37.42206192085422}},
#               {'attributes': {'Aproximaci': 'Calle Cataluña',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Navarra',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 249,
#                               'Lat_Y': 37.424799,
#                               'Lon_X': -5.984816,
#                               'id_estacio': 249},
#                'geometry': {'x': -5.984816272985105, 'y': 37.42479928120684}},
#               {'attributes': {'Aproximaci': 'Calle de Marruecos',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle de Salvador Allende',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 250,
#                               'Lat_Y': 37.42191,
#                               'Lon_X': -5.985423,
#                               'id_estacio': 250},
#                'geometry': {'x': -5.985422635801886, 'y': 37.42190996124914}},
#               {'attributes': {'Aproximaci': 'Esquina a Calle Alejandro '
#                                             'Collantes',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida Cruzcampo',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 251,
#                               'Lat_Y': 37.385783,
#                               'Lon_X': -5.96515,
#                               'id_estacio': 251},
#                'geometry': {'x': -5.965150354785167, 'y': 37.38578334194045}},
#               {'attributes': {'Aproximaci': 'Calle Calderas',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Carretera de Bellavista',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 252,
#                               'Lat_Y': 37.324607,
#                               'Lon_X': -5.968985,
#                               'id_estacio': 252},
#                'geometry': {'x': -5.96898526273306, 'y': 37.32460686517982}},
#               {'attributes': {'Aproximaci': 'Hospital Valme',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Carretera de Bellavista',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 253,
#                               'Lat_Y': 37.319697,
#                               'Lon_X': -5.969165,
#                               'id_estacio': 253},
#                'geometry': {'x': -5.969164925789884, 'y': 37.31969696260066}},
#               {'attributes': {'Aproximaci': 'Avenida de Jerez',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Carretera de Bellavista',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 254,
#                               'Lat_Y': 37.328766,
#                               'Lon_X': -5.967814,
#                               'id_estacio': 254},
#                'geometry': {'x': -5.967813859602582, 'y': 37.328765708185834}},
#               {'attributes': {'Aproximaci': 'Rotonda de Torreblanca',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Pero Mingo',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 255,
#                               'Lat_Y': 37.385974,
#                               'Lon_X': -5.914097,
#                               'id_estacio': 255},
#                'geometry': {'x': -5.914097300558093, 'y': 37.385973918329846}},
#               {'attributes': {'Aproximaci': 'Calle Pero Mingo',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Plaza Miguel Montoro',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 256,
#                               'Lat_Y': 37.385987,
#                               'Lon_X': -5.910274,
#                               'id_estacio': 256},
#                'geometry': {'x': -5.9102740707088675, 'y': 37.385986766158865}},
#               {'attributes': {'Aproximaci': 'Plaza Corazón de María',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Plaza Torres de Albarracín',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 257,
#                               'Lat_Y': 37.38421,
#                               'Lon_X': -5.909692,
#                               'id_estacio': 257},
#                'geometry': {'x': -5.909691962404751, 'y': 37.38421017601403}},
#               {'attributes': {'Aproximaci': 'Calle Creus',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle Estaca de Vares',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 258,
#                               'Lat_Y': 37.383797,
#                               'Lon_X': -5.914633,
#                               'id_estacio': 258},
#                'geometry': {'x': -5.914632696467408, 'y': 37.38379689328399}},
#               {'attributes': {'Aproximaci': 'Calle Aguila Perdicera',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Calle 8 de Marzo',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 259,
#                               'Lat_Y': 37.367181,
#                               'Lon_X': -5.954483,
#                               'id_estacio': 259},
#                'geometry': {'x': -5.954482860786248, 'y': 37.36718089848917}},
#               {'attributes': {'Aproximaci': 'Centro Deportivo Amate',
#                               'CreationDate': 1412457692379,
#                               'Creator': 'Ayto.Sevilla',
#                               'Direccion': 'Avenida de la Revoltosa',
#                               'EditDate': 1412457692379,
#                               'Editor': 'Ayto.Sevilla',
#                               'FID': 260,
#                               'Lat_Y': 37.378641,
#                               'Lon_X': -5.948474,
#                               'id_estacio': 260},
#                'geometry': {'x': -5.948474029850786, 'y': 37.37864101761935}}],
#  'fields': [{'alias': 'FID',
#              'defaultValue': None,
#              'domain': None,
#              'name': 'FID',
#              'sqlType': 'sqlTypeInteger',
#              'type': 'esriFieldTypeInteger'},
#             {'alias': 'id_estacio',
#              'defaultValue': None,
#              'domain': None,
#              'name': 'id_estacio',
#              'sqlType': 'sqlTypeFloat',
#              'type': 'esriFieldTypeDouble'},
#             {'alias': 'Direccion',
#              'defaultValue': None,
#              'domain': None,
#              'length': 254,
#              'name': 'Direccion',
#              'sqlType': 'sqlTypeNVarchar',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'Aproximaci',
#              'defaultValue': None,
#              'domain': None,
#              'length': 254,
#              'name': 'Aproximaci',
#              'sqlType': 'sqlTypeNVarchar',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'Lat_Y',
#              'defaultValue': None,
#              'domain': None,
#              'name': 'Lat_Y',
#              'sqlType': 'sqlTypeFloat',
#              'type': 'esriFieldTypeDouble'},
#             {'alias': 'Lon_X',
#              'defaultValue': None,
#              'domain': None,
#              'name': 'Lon_X',
#              'sqlType': 'sqlTypeFloat',
#              'type': 'esriFieldTypeDouble'},
#             {'alias': 'CreationDate',
#              'defaultValue': None,
#              'domain': None,
#              'length': 8,
#              'name': 'CreationDate',
#              'sqlType': 'sqlTypeOther',
#              'type': 'esriFieldTypeDate'},
#             {'alias': 'Creator',
#              'defaultValue': None,
#              'domain': None,
#              'length': 50,
#              'name': 'Creator',
#              'sqlType': 'sqlTypeOther',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'EditDate',
#              'defaultValue': None,
#              'domain': None,
#              'length': 8,
#              'name': 'EditDate',
#              'sqlType': 'sqlTypeOther',
#              'type': 'esriFieldTypeDate'},
#             {'alias': 'Editor',
#              'defaultValue': None,
#              'domain': None,
#              'length': 50,
#              'name': 'Editor',
#              'sqlType': 'sqlTypeOther',
#              'type': 'esriFieldTypeString'}],
#  'geometryType': 'esriGeometryPoint',
#  'globalIdFieldName': '',
#  'objectIdFieldName': 'FID',
#  'spatialReference': {'latestWkid': 4326, 'wkid': 4326},
#  'uniqueIdField': {'isSystemMaintained': True, 'name': 'FID'}}

# %% [markdown]
# Ahora podemos escribir los datos en un dataframe de pandas que nos permita usar todo lo que hemos aprendido hasta ahora

# %%
data = [x["attributes"] for x in raw_data["features"]]
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#      FID  id_estacio                   Direccion  \
# 0      1           1           Glorieta Olimpica
# 1      2           2                  Gran Plaza
# 2      3           3       Puerta de la Barqueta
# 3      4           4     Calle Leonardo Da Vinci
# 4      5         131            Calle Tabladilla
# ..   ...         ...                         ...
# 255  256         256        Plaza Miguel Montoro
# 256  257         257  Plaza Torres de Albarracín
# 257  258         258       Calle Estaca de Vares
# 258  259         259            Calle 8 de Marzo
# 259  260         260     Avenida de la Revoltosa
#
#                             Aproximaci      Lat_Y     Lon_X   CreationDate  \
# 0    Concejal Alberto Jiménez-Becerril  37.412983 -5.988933  1412457692379
# 1             Calle Marquez de Pickman  37.381664 -5.965183  1412457692379
# 2                Puente de la Barqueta  37.405640 -5.998514  1412457692379
# 3             Calle Thomas Alba Edison  37.410126 -6.005659  1412457692379
# 4              Calle Cardenal Ilundaín  37.364746 -5.981396  1412457692379
# ..                                 ...        ...       ...            ...
# 255                   Calle Pero Mingo  37.385987 -5.910274  1412457692379
# 256             Plaza Corazón de María  37.384210 -5.909692  1412457692379
# 257                        Calle Creus  37.383797 -5.914633  1412457692379
# 258             Calle Aguila Perdicera  37.367181 -5.954483  1412457692379
# 259             Centro Deportivo Amate  37.378641 -5.948474  1412457692379
#
#           Creator       EditDate        Editor
# 0    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 1    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 2    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 3    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 4    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# ..            ...            ...           ...
# 255  Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 256  Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 257  Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 258  Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 259  Ayto.Sevilla  1412457692379  Ayto.Sevilla
#
# [260 rows x 10 columns]

# %% [markdown]
# Parece que el lugar en el que es más necesario especificar la aproximación es en la Calle Asunción

# %%
df.groupby('Aproximaci')['FID'].count().sort_values(ascending=False)
# Out:
# Aproximaci
# Calle Asunción                    3
# Calle Profesor García González    2
# Calle Pino Montano                2
# Calle Albert Einstein             2
# Calle Fray Isidoro de Sevilla     2
#                                  ..
# Calle Flor de Salvia              1
# Calle Fuenteovejuna               1
# Calle Gonzalo de Bilbao           1
# Calle González Cuadrado           1
# Virgen de la Victoria             1
# Name: FID, Length: 242, dtype: int64

# %% [markdown]
# Podemos sacar las posiciones de las estaciones que más nos interesen

# %%
df.loc[0, ["Lat_Y", "Lon_X"]].values
# Out:
# array([37.412983, -5.988933], dtype=object)

# %% [markdown]
# Con el módulo `geopy` se puede encontrar la distancia geodésica (camino más corto sobre la superficie terrestre) entre dos estaciones de sevici

# %%
from geopy.distance import geodesic
point1 = df.loc[0, ["Lat_Y", "Lon_X"]].values
name1 = df.loc[0, ["Direccion"]].values[0]
point2 = df.loc[2, ["Lat_Y", "Lon_X"]].values
name2 = df.loc[2, ["Direccion"]].values[0]
d = geodesic(point1, point2).km

print(f"La distancia entre {name1} y {name2} es de {d:.2f} km")
# Out:
# La distancia entre Glorieta Olimpica y Puerta de la Barqueta es de 1.18 km

# %% [markdown]
# ## Ejemplo 2: OpenStreet Maps

# %%
import requests
import json
import pandas as pd
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
node["amenity"="library"]
  (37.3953289, -5.9914891, 37.3998008, -5.9916412); 
out;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
print(response)
data = response.json()
# Out:
# <Response [200]>

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.1 084b4234',
#  'osm3s': {'timestamp_osm_base': '2024-07-08T19:03:45Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 825689323,
#    'lat': 37.3982329,
#    'lon': -5.9916821,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '57',
#     'addr:street': 'Calle Feria',
#     'amenity': 'library',
#     'contact:phone': '+34 955472081',
#     'contact:website': 'http://www.rmbs.es/blog/biblioteca-alberto-lista',
#     'name': 'Biblioteca Alberto Lista',
#     'operator': 'Red Municipal de Bibliotecas - Casco Antigüo (Ayto. de Sevilla)',
#     'operator:type': 'public',
#     'source': 'Portal de Datos Abiertos (Ayto. Sevilla)',
#     'wikidata': 'Q85685852'}},
#   {'type': 'node',
#    'id': 825921972,
#    'lat': 37.3991257,
#    'lon': -5.9843529,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '4',
#     'addr:street': 'Ronda de Capuchinos',
#     'amenity': 'library',
#     'contact:phone': '+34 954988243',
#     'contact:website': 'http://www.rmbs.es/blog/biblioteca-san-julian',
#     'name': 'Biblioteca San Julian',
#     'operator': 'Red Municipal de Bibliotecas - Casco Antigüo (Ayto. de Sevilla)',
#     'operator:type': 'public',
#     'source': 'Portal de Datos Abiertos (Ayto. Sevilla)',
#     'wikidata': 'Q85685877'}},
#   {'type': 'node',
#    'id': 4296824021,
#    'lat': 37.3973363,
#    'lon': -6.1424391,
#    'tags': {'amenity': 'library',
#     'name': 'Biblioteca Pública Municipal "Federico García Lorca"'}},
#   {'type': 'node',
#    'id': 8962315387,
#    'lat': 37.3969988,
#    'lon': -5.9189039,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '1',
#     'addr:postcode': '41020',
#     'addr:street': 'Calle Flor de Retama',
#     'amenity': 'library',
#     'contact:phone': '+34 954474208',
#     'contact:website': 'http://www.rmbs.es/blog/biblioteca-blas-infante',
#     'name': 'Biblioteca Blas Infantes',
#     'operator': 'Red Municipal de Bibliotecas (Ayto. de Sevilla)',
#     'operator:type': 'public',
#     'source': 'Portal de Datos Abiertos (Ayto. Sevilla)',
#     'wikidata': 'Q85685855'}}]}

# %%
elements = data['elements']
places = {'lat': [], 'lon': [], 'name': [], 'address': [], 'website': []}
for i in elements:
    try:
        latitude = i['lat']
        longitude = i['lon']
        name = i['tags']['name']
        street = i['tags']['addr:street']
        number = i['tags']['addr:housenumber']
        website = i['tags']["contact:website"]
        
        places['lat'].append(latitude)
        places['lon'].append(longitude)
        places['name'].append(name)
        places['address'].append(street + ' ' + str(number))
        places["website"].append(website)
    except:
        continue


df = pd.DataFrame(places)
df[(df['lon']<-4)&(df['lon']>-7)]
# Out:
#          lat       lon                      name                 address  \
# 0  37.398233 -5.991682  Biblioteca Alberto Lista          Calle Feria 57
# 1  37.399126 -5.984353     Biblioteca San Julian   Ronda de Capuchinos 4
# 2  37.396999 -5.918904  Biblioteca Blas Infantes  Calle Flor de Retama 1
#
#                                             website
# 0  http://www.rmbs.es/blog/biblioteca-alberto-lista
# 1     http://www.rmbs.es/blog/biblioteca-san-julian
# 2   http://www.rmbs.es/blog/biblioteca-blas-infante

# %%
i.get("sevilla")

# %%
i["sevilla"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 i["sevilla"]
#
# KeyError: 'sevilla'

# %%
i.get("tags")
# Out:
# {'addr:city': 'Sevilla',
#  'addr:housenumber': '1',
#  'addr:postcode': '41020',
#  'addr:street': 'Calle Flor de Retama',
#  'amenity': 'library',
#  'contact:phone': '+34 954474208',
#  'contact:website': 'http://www.rmbs.es/blog/biblioteca-blas-infante',
#  'name': 'Biblioteca Blas Infantes',
#  'operator': 'Red Municipal de Bibliotecas (Ayto. de Sevilla)',
#  'operator:type': 'public',
#  'source': 'Portal de Datos Abiertos (Ayto. Sevilla)',
#  'wikidata': 'Q85685855'}

# %%
from flask import Flask, request, jsonify

# %%
app = Flask(__name__)
app.config['DEBUG'] = False

# %%
books = [ 
            {'id': 0, 
            'title': 'A Fire Upon the Deep', 
            'author': 'Vernor Vinge', 
            'first_sentence': 'The coldsleep itself was dreamless.', 
            'year_published': '1992'},
            
            {'id': 1, 
            'title': 'The Ones Who Walk Away From Omelas', 
            'author': 'Ursula K. Le Guin', 
            'first_sentence': 'With a clamor of bells that set the swallows soaring, the Festival of Summer came to the city Omelas, bright-towered by the sea.', 
            'published': '1973'},

            {'id': 2, 
            'title': 'Dhalgren', 
            'author': 'Samuel R. Delany', 
            'first_sentence': 'to wound the autumnal city.', 
            'published': '1975'} 
        ]

# %%
@app.route('/', methods=['GET'])
def home():
	return "<h1>La Enciclopedia de Hari Seldon</h1><p>This site is a prototype API for distant reading of science fiction novels.</p>"


# GET Display all the books
@app.route('/api/v1/resources/books/all', methods=['GET']) 
def api_all():
    return jsonify(books)
    #return books

@app.route('/api/v1/resources/books/1', methods=['GET']) 
def api_1():
    return jsonify(books[0])

app.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [08/Jul/2024 21:22:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jul/2024 21:22:45] "GET /api/v1/resources/books/1 HTTP/1.1" 200 -

# %% [markdown]
# ## SPARK(LING) DIAMONDS
#
# Este ejercicio debes ejecutarlo en DataBricks y utilizando Dataframes de pyspark
#
# 1. Carga en un dataframe el dataset de clasificación de diamantes que tiene DataBricks, lo puedes encontrar en
# "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv"

# %%
df = spark.read.csv("/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv", header = True, inferSchema = True)

# %% [markdown]
# 2. Muestra el esquema

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- carat: double (nullable = true)
#  |-- cut: string (nullable = true)
#  |-- color: string (nullable = true)
#  |-- clarity: string (nullable = true)
#  |-- depth: double (nullable = true)
#  |-- table: double (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- x: double (nullable = true)
#  |-- y: double (nullable = true)
#  |-- z: double (nullable = true)

# %% [markdown]
# 3. Muestra las 10 primeras filas de, como mínimo, dos formas diferentes

# %%
df.show(10)
# Out:
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
# |_c0|carat|      cut|color|clarity|depth|table|price|   x|   y|   z|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
# |  1| 0.23|    Ideal|    E|    SI2| 61.5| 55.0|  326|3.95|3.98|2.43|
# |  2| 0.21|  Premium|    E|    SI1| 59.8| 61.0|  326|3.89|3.84|2.31|
# |  3| 0.23|     Good|    E|    VS1| 56.9| 65.0|  327|4.05|4.07|2.31|
# |  4| 0.29|  Premium|    I|    VS2| 62.4| 58.0|  334| 4.2|4.23|2.63|
# |  5| 0.31|     Good|    J|    SI2| 63.3| 58.0|  335|4.34|4.35|2.75|
# |  6| 0.24|Very Good|    J|   VVS2| 62.8| 57.0|  336|3.94|3.96|2.48|
# |  7| 0.24|Very Good|    I|   VVS1| 62.3| 57.0|  336|3.95|3.98|2.47|
# |  8| 0.26|Very Good|    H|    SI1| 61.9| 55.0|  337|4.07|4.11|2.53|
# |  9| 0.22|     Fair|    E|    VS2| 65.1| 61.0|  337|3.87|3.78|2.49|
# | 10| 0.23|Very Good|    H|    VS1| 59.4| 61.0|  338| 4.0|4.05|2.39|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
# only showing top 10 rows

# %%
df.limit(10).toPandas().head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>carat</th>
#       <th>cut</th>
#       <th>color</th>
#       <th>clarity</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0.23</td>
#       <td>Ideal</td>
#       <td>E</td>
#       <td>SI2</td>
#       <td>61.5</td>
#       <td>55.0</td>
#       <td>326</td>
#       <td>3.95</td>
#       <td>3.98</td>
#       <td>2.43</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>0.21</td>
#       <td>Premium</td>
#       <td>E</td>
#       <td>SI1</td>
#       <td>59.8</td>
#       <td>61.0</td>
#       <td>326</td>
#       <td>3.89</td>
#       <td>3.84</td>
#       <td>2.31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>0.23</td>
#       <td>Good</td>
#       <td>E</td>
#       <td>VS1</td>
#       <td>56.9</td>
#       <td>65.0</td>
#       <td>327</td>
#       <td>4.05</td>
#       <td>4.07</td>
#       <td>2.31</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>0.29</td>
#       <td>Premium</td>
#       <td>I</td>
#       <td>VS2</td>
#       <td>62.4</td>
#       <td>58.0</td>
#       <td>334</td>
#       <td>4.20</td>
#       <td>4.23</td>
#       <td>2.63</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>0.31</td>
#       <td>Good</td>
#       <td>J</td>
#       <td>SI2</td>
#       <td>63.3</td>
#       <td>58.0</td>
#       <td>335</td>
#       <td>4.34</td>
#       <td>4.35</td>
#       <td>2.75</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>0.24</td>
#       <td>Very Good</td>
#       <td>J</td>
#       <td>VVS2</td>
#       <td>62.8</td>
#       <td>57.0</td>
#       <td>336</td>
#       <td>3.94</td>
#       <td>3.96</td>
#       <td>2.48</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>0.24</td>
#       <td>Very Good</td>
#       <td>I</td>
#       <td>VVS1</td>
#       <td>62.3</td>
#       <td>57.0</td>
#       <td>336</td>
#       <td>3.95</td>
#       <td>3.98</td>
#       <td>2.47</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>0.26</td>
#       <td>Very Good</td>
#       <td>H</td>
#       <td>SI1</td>
#       <td>61.9</td>
#       <td>55.0</td>
#       <td>337</td>
#       <td>4.07</td>
#       <td>4.11</td>
#       <td>2.53</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>0.22</td>
#       <td>Fair</td>
#       <td>E</td>
#       <td>VS2</td>
#       <td>65.1</td>
#       <td>61.0</td>
#       <td>337</td>
#       <td>3.87</td>
#       <td>3.78</td>
#       <td>2.49</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>0.23</td>
#       <td>Very Good</td>
#       <td>H</td>
#       <td>VS1</td>
#       <td>59.4</td>
#       <td>61.0</td>
#       <td>338</td>
#       <td>4.00</td>
#       <td>4.05</td>
#       <td>2.39</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</th></tr></thead><tbody><tr><td>1</td><td>0.23</td><td>Ideal</td><td>E</td><td>SI2</td><td>61.5</td><td>55.0</td><td>326</td><td>3.95</td><td>3.98</td><td>2.43</td></tr><tr><td>2</td><td>0.21</td><td>Premium</td><td>E</td><td>SI1</td><td>59.8</td><td>61.0</td><td>326</td><td>3.89</td><td>3.84</td><td>2.31</td></tr><tr><td>3</td><td>0.23</td><td>Good</td><td>E</td><td>VS1</td><td>56.9</td><td>65.0</td><td>327</td><td>4.05</td><td>4.07</td><td>2.31</td></tr><tr><td>4</td><td>0.29</td><td>Premium</td><td>I</td><td>VS2</td><td>62.4</td><td>58.0</td><td>334</td><td>4.2</td><td>4.23</td><td>2.63</td></tr><tr><td>5</td><td>0.31</td><td>Good</td><td>J</td><td>SI2</td><td>63.3</td><td>58.0</td><td>335</td><td>4.34</td><td>4.35</td><td>2.75</td></tr><tr><td>6</td><td>0.24</td><td>Very Good</td><td>J</td><td>VVS2</td><td>62.8</td><td>57.0</td><td>336</td><td>3.94</td><td>3.96</td><td>2.48</td></tr><tr><td>7</td><td>0.24</td><td>Very Good</td><td>I</td><td>VVS1</td><td>62.3</td><td>57.0</td><td>336</td><td>3.95</td><td>3.98</td><td>2.47</td></tr><tr><td>8</td><td>0.26</td><td>Very Good</td><td>H</td><td>SI1</td><td>61.9</td><td>55.0</td><td>337</td><td>4.07</td><td>4.11</td><td>2.53</td></tr><tr><td>9</td><td>0.22</td><td>Fair</td><td>E</td><td>VS2</td><td>65.1</td><td>61.0</td><td>337</td><td>3.87</td><td>3.78</td><td>2.49</td></tr><tr><td>10</td><td>0.23</td><td>Very Good</td><td>H</td><td>VS1</td><td>59.4</td><td>61.0</td><td>338</td><td>4.0</td><td>4.05</td><td>2.39</td></tr></tbody></table></div>

# %% [markdown]
# 4. Codifica ordinalmente la columna "cut" y guarda el resultado en una nueva columna llamada "target"

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol = "cut", outputCol = "target")

# %%
model_indexer = indexer.fit(df)
print(model_indexer.labelsArray)
# Out:
# [('Ideal', 'Premium', 'Very Good', 'Good', 'Fair')]

# %%
df_new = model_indexer.transform(df)

# %%
df_new.show(10)
# Out:
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+
# |_c0|carat|      cut|color|clarity|depth|table|price|   x|   y|   z|target|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+
# |  1| 0.23|    Ideal|    E|    SI2| 61.5| 55.0|  326|3.95|3.98|2.43|   0.0|
# |  2| 0.21|  Premium|    E|    SI1| 59.8| 61.0|  326|3.89|3.84|2.31|   1.0|
# |  3| 0.23|     Good|    E|    VS1| 56.9| 65.0|  327|4.05|4.07|2.31|   3.0|
# |  4| 0.29|  Premium|    I|    VS2| 62.4| 58.0|  334| 4.2|4.23|2.63|   1.0|
# |  5| 0.31|     Good|    J|    SI2| 63.3| 58.0|  335|4.34|4.35|2.75|   3.0|
# |  6| 0.24|Very Good|    J|   VVS2| 62.8| 57.0|  336|3.94|3.96|2.48|   2.0|
# |  7| 0.24|Very Good|    I|   VVS1| 62.3| 57.0|  336|3.95|3.98|2.47|   2.0|
# |  8| 0.26|Very Good|    H|    SI1| 61.9| 55.0|  337|4.07|4.11|2.53|   2.0|
# |  9| 0.22|     Fair|    E|    VS2| 65.1| 61.0|  337|3.87|3.78|2.49|   4.0|
# | 10| 0.23|Very Good|    H|    VS1| 59.4| 61.0|  338| 4.0|4.05|2.39|   2.0|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+
# only showing top 10 rows

# %%
df_new.groupBy("target").count().show()
# Out:
# +------+-----+
# |target|count|
# +------+-----+
# |   0.0|21551|
# |   1.0|13791|
# |   4.0| 1610|
# |   3.0| 4906|
# |   2.0|12082|
# +------+-----+

# %% [markdown]
# 5. Crea el vector de features empleando como mínimo las variables numéricas que tiene el dataframe de partida

# %%
from pyspark.ml.feature import VectorAssembler

features_in = ["carat","depth","table","price","x","y","z"]
vector = VectorAssembler(inputCols= features_in, outputCol= "Vector_Features")

# %%
df_new_features = vector.transform(df_new)

# %%
df_new_features.show(10)
# Out:
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+--------------------+
# |_c0|carat|      cut|color|clarity|depth|table|price|   x|   y|   z|target|     Vector_Features|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+--------------------+
# |  1| 0.23|    Ideal|    E|    SI2| 61.5| 55.0|  326|3.95|3.98|2.43|   0.0|[0.23,61.5,55.0,3...|
# |  2| 0.21|  Premium|    E|    SI1| 59.8| 61.0|  326|3.89|3.84|2.31|   1.0|[0.21,59.8,61.0,3...|
# |  3| 0.23|     Good|    E|    VS1| 56.9| 65.0|  327|4.05|4.07|2.31|   3.0|[0.23,56.9,65.0,3...|
# |  4| 0.29|  Premium|    I|    VS2| 62.4| 58.0|  334| 4.2|4.23|2.63|   1.0|[0.29,62.4,58.0,3...|
# |  5| 0.31|     Good|    J|    SI2| 63.3| 58.0|  335|4.34|4.35|2.75|   3.0|[0.31,63.3,58.0,3...|
# |  6| 0.24|Very Good|    J|   VVS2| 62.8| 57.0|  336|3.94|3.96|2.48|   2.0|[0.24,62.8,57.0,3...|
# |  7| 0.24|Very Good|    I|   VVS1| 62.3| 57.0|  336|3.95|3.98|2.47|   2.0|[0.24,62.3,57.0,3...|
# |  8| 0.26|Very Good|    H|    SI1| 61.9| 55.0|  337|4.07|4.11|2.53|   2.0|[0.26,61.9,55.0,3...|
# |  9| 0.22|     Fair|    E|    VS2| 65.1| 61.0|  337|3.87|3.78|2.49|   4.0|[0.22,65.1,61.0,3...|
# | 10| 0.23|Very Good|    H|    VS1| 59.4| 61.0|  338| 4.0|4.05|2.39|   2.0|[0.23,59.4,61.0,3...|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+--------------------+
# only showing top 10 rows

# %% [markdown]
# 6. Divide el dataframe en un dataset de train y un dataset de test, al 70-30

# %%
(train,test) = df_new_features.randomSplit((0.7,0.3))

# %%
train.count()
# Out:
# Out[15]: 37845

# %%
test.count()
# Out:
# Out[16]: 16095

# %%
display(train)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</
0</td><td>Map(vectorType -> dense, length -> 7, values -> List(0.33, 61.2, 56.0, 403.0, 4.49, 4.5, 2.75))</td></tr><tr><td>42</td><td>0.33</td><td>Ideal</td><td>J</td><td>SI1</td><td>61.1</td><td>56.0</td><td>403</td><td>4.49</td><td>4.55</td><td>2.76</td><td>0.0</td><td>Map(vectorType -> dense, length -> 7, values -> List(0.33, 61.1, 56.0, 403.0, 4.49, 4.55, 2.76))</td></tr><t ...

# %% [markdown]
# 7. Entrena un Clasificador RandomForest con al menos tres valores diferentes de estimadores

# %%
from pyspark.ml.classification import RandomForestClassifier

num_tress = [10,50,1000]

models = {}

for indice,tress in enumerate(num_tress):
    model = RandomForestClassifier(featuresCol="Vector_Features", labelCol= "target", numTrees = tress)
    models["modelo_{}".format(indice)] = model.fit(train)

# %% [markdown]
# 8. Evalua por separado cada modelo, muestra la precision y recall por categoría (con su etiqueta original), así como el accuracy medio

# %%
evaluations = {}
for indice in range(3):
    evaluations["modelo_{}".format(indice)] = models["modelo_{}".format(indice)].evaluate(test)

# %%
for indice in range(3):
    print("Evaluacion Modelo con {} estimadores".format(num_tress[indice]))
    print("Class\tPrecision\tRecall")
    print("-"*30)
    for clase,precision,recall in zip(model_indexer.labels, evaluations["modelo_{}".format(indice)].precisionByLabel, evaluations["modelo_{}".format(indice)].recallByLabel):
        print("%s\t%.3f\t%.3f" %(clase,precision,recall))
    print()
    print("Accuracy medio: %.3f" %(evaluations["modelo_{}".format(indice)].accuracy))
    print("*"*30)
# Out:
# Evaluacion Modelo con 10 estimadores
# Class	Precision	Recall
# ------------------------------
# Ideal	0.785	0.941
# Premium	0.628	0.861
# Very Good	0.634	0.219
# Good	0.684	0.451
# Fair	0.709	0.706
#
# Accuracy medio: 0.709
# ******************************
# Evaluacion Modelo con 50 estimadores
# Class	Precision	Recall
# ------------------------------
# Ideal	0.788	0.938
# Premium	0.622	0.865
# Very Good	0.626	0.237
# Good	0.726	0.406
# Fair	0.712	0.715
#
# Accuracy medio: 0.709
# ******************************
# Evaluacion Modelo con 1000 estimadores
# Class	Precision	Recall
# ------------------------------
# Ideal	0.785	0.940
# Premium	0.622	0.865
# Very Good	0.633	0.225
# Good	0.711	0.418
# Fair	0.709	0.704
#
# Accuracy medio: 0.708
# ******************************

# %% [markdown]
# ¿Cuál es el mejor?¿

# %% [markdown]
# No parece que haya grandes diferencias, deberíamos ver si alguno de ellos está overfitteando, de todas formas

# %%
for i in range(3):
    print("Modelo con %d estimadores" %(num_tress[i]))
    evaluation = models["modelo_{}".format(i)].evaluate(train)
    print("Accuracy: %.3f" %(evaluation.accuracy))
# Out:
# Modelo con 10 estimadores
# Accuracy: 0.710
# Modelo con 50 estimadores
# Accuracy: 0.710
# Modelo con 1000 estimadores
# Accuracy: 0.710

# %% [markdown]
# Partiríamos del segundo (50 árboles) e intentaríamos mejorar los resultados a partir de ahí

# %% [markdown]
# __Para Nota__: Haz un onehotencoding o un ordinalencoding de las variables categoricas y entrena un GBT con 20 estimadores

# %% [markdown]
# Importamos todo lo necesario

# %%
from pyspark.sql.functions import col,udf
from pyspark.sql.types import StringType
from pyspark.ml.classification import GBTClassifier, OneVsRest
from pyspark.ml.feature import OneHotEncoder

# %% [markdown]
# Vamos a hacer el ordinal encoding de la feature Clarity pero para ello necesitamos ordenarlo de forma que el StringIndexer lo ajuste a la escala:
# https://www.americangemsociety.org/buying-diamonds-with-confidence/4cs-of-diamonds/understanding-diamond-clarity-the-4cs-of-diamonds/diamond-clarity-scale/#:~:text=A%20diamond%20with%20a%20clarity,to%20see%20under%2010x%20magnification.&text=Very%20Slightly%20Included%20diamonds%20with,or%20VS2)%20have%20minor%20inclusions.

# %%
df_new.groupBy("Clarity").count().show()
# Out:
# +-------+-----+
# |Clarity|count|
# +-------+-----+
# |   VVS2| 5066|
# |    SI1|13065|
# |     IF| 1790|
# |     I1|  741|
# |   VVS1| 3655|
# |    VS2|12258|
# |    SI2| 9194|
# |    VS1| 8171|
# +-------+-----+

# %%
def prepare_clarity(row):
    return "Z_IF" if row == "IF" else row.replace("2","a").replace("1","b")

# %%
udf_prepare = udf(lambda row: prepare_clarity(row), StringType())

# %%
df_new_prepared = df_new.withColumn("Ord_Clarity", udf_prepare(col("Clarity")))

# %%
df_new_prepared.groupBy("clarity").count().show()
# Out:
# +-------+-----+
# |clarity|count|
# +-------+-----+
# |   VVS2| 5066|
# |    SI1|13065|
# |     IF| 1790|
# |     I1|  741|
# |   VVS1| 3655|
# |    VS2|12258|
# |    SI2| 9194|
# |    VS1| 8171|
# +-------+-----+

# %%
df_new_prepared.groupBy("Ord_Clarity").count().show()
# Out:
# +-----------+-----+
# |Ord_Clarity|count|
# +-----------+-----+
# |       Z_IF| 1790|
# |        VSb| 8171|
# |       VVSa| 5066|
# |         Ib|  741|
# |       VVSb| 3655|
# |        VSa|12258|
# |        SIb|13065|
# |        SIa| 9194|
# +-----------+-----+

# %% [markdown]
# Aprovechamos para hacer el ordinal encoder de Color que necesitamos como paso previo a su onehotencoding

# %%
indexer_clarity = StringIndexer(inputCols = ["Ord_Clarity","color"], outputCols= ["feat_clarity","Ord_Color"], stringOrderType= "alphabetAsc")
indexer_model_clarity = indexer_clarity.fit(df_new_prepared)

# %%
indexer_model_clarity.labelsArray
# Out:
# Out[31]: [('Ib', 'SIa', 'SIb', 'VSa', 'VSb', 'VVSa', 'VVSb', 'Z_IF'),
#  ('D', 'E', 'F', 'G', 'H', 'I', 'J')]

# %%
df_new_feat_clarity = indexer_model_clarity.transform(df_new_prepared)

# %%
df_new_feat_clarity.show(10)
# Out:
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+
# |_c0|carat|      cut|color|clarity|depth|table|price|   x|   y|   z|target|Ord_Clarity|feat_clarity|Ord_Color|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+
# |  1| 0.23|    Ideal|    E|    SI2| 61.5| 55.0|  326|3.95|3.98|2.43|   0.0|        SIa|         1.0|      1.0|
# |  2| 0.21|  Premium|    E|    SI1| 59.8| 61.0|  326|3.89|3.84|2.31|   1.0|        SIb|         2.0|      1.0|
# |  3| 0.23|     Good|    E|    VS1| 56.9| 65.0|  327|4.05|4.07|2.31|   3.0|        VSb|         4.0|      1.0|
# |  4| 0.29|  Premium|    I|    VS2| 62.4| 58.0|  334| 4.2|4.23|2.63|   1.0|        VSa|         3.0|      5.0|
# |  5| 0.31|     Good|    J|    SI2| 63.3| 58.0|  335|4.34|4.35|2.75|   3.0|        SIa|         1.0|      6.0|
# |  6| 0.24|Very Good|    J|   VVS2| 62.8| 57.0|  336|3.94|3.96|2.48|   2.0|       VVSa|         5.0|      6.0|
# |  7| 0.24|Very Good|    I|   VVS1| 62.3| 57.0|  336|3.95|3.98|2.47|   2.0|       VVSb|         6.0|      5.0|
# |  8| 0.26|Very Good|    H|    SI1| 61.9| 55.0|  337|4.07|4.11|2.53|   2.0|        SIb|         2.0|      4.0|
# |  9| 0.22|     Fair|    E|    VS2| 65.1| 61.0|  337|3.87|3.78|2.49|   4.0|        VSa|         3.0|      1.0|
# | 10| 0.23|Very Good|    H|    VS1| 59.4| 61.0|  338| 4.0|4.05|2.39|   2.0|        VSb|         4.0|      4.0|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+
# only showing top 10 rows

# %% [markdown]
# Ahora a hacer el one_hot_encoding del color

# %%
oHEncoder = OneHotEncoder(inputCol= "Ord_Color", outputCol= "Color_Encoded")
oHModel = oHEncoder.fit(df_new_feat_clarity)

# %%
df_pre_train = oHModel.transform(df_new_feat_clarity)

# %%
df_pre_train.show()
# Out:
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+-------------+
# |_c0|carat|      cut|color|clarity|depth|table|price|   x|   y|   z|target|Ord_Clarity|feat_clarity|Ord_Color|Color_Encoded|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+-------------+
# |  1| 0.23|    Ideal|    E|    SI2| 61.5| 55.0|  326|3.95|3.98|2.43|   0.0|        SIa|         1.0|      1.0|(6,[1],[1.0])|
# |  2| 0.21|  Premium|    E|    SI1| 59.8| 61.0|  326|3.89|3.84|2.31|   1.0|        SIb|         2.0|      1.0|(6,[1],[1.0])|
# |  3| 0.23|     Good|    E|    VS1| 56.9| 65.0|  327|4.05|4.07|2.31|   3.0|        VSb|         4.0|      1.0|(6,[1],[1.0])|
# |  4| 0.29|  Premium|    I|    VS2| 62.4| 58.0|  334| 4.2|4.23|2.63|   1.0|        VSa|         3.0|      5.0|(6,[5],[1.0])|
# |  5| 0.31|     Good|    J|    SI2| 63.3| 58.0|  335|4.34|4.35|2.75|   3.0|        SIa|         1.0|      6.0|    (6,[],[])|
# |  6| 0.24|Very Good|    J|   VVS2| 62.8| 57.0|  336|3.94|3.96|2.48|   2.0|       VVSa|         5.0|      6.0|    (6,[],[])|
# |  7| 0.24|Very Good|    I|   VVS1| 62.3| 57.0|  336|3.95|3.98|2.47|   2.0|       VVSb|         6.0|      5.0|(6,[5],[1.0])|
# |  8| 0.26|Very Good|    H|    SI1| 61.9| 55.0|  337|4.07|4.11|2.53|   2.0|        SIb|         2.0|      4.0|(6,[4],[1.0])|
# |  9| 0.22|     Fair|    E|    VS2| 65.1| 61.0|  337|3.87|3.78|2.49|   4.0|        VSa|         3.0|      1.0|(6,[1],[1.0])|
# | 10| 0.23|Very Good|    H|    VS1| 59.4| 61.0|  338| 4.0|4.05|2.39|   2.0|        VSb|         4.0|      4.0|(6,[4],[1.0])|
# | 11|  0.3|     Good|    J|    SI1| 64.0| 55.0|  339|4.25|4.28|2.73|   3.0|        SIb|         2.0|      6.0|    (6,[],[])|
# | 12| 0.23|    Ideal|    J|    VS1| 62.8| 56.0|  340|3.93| 3.9|2.46|   0.0|        VSb|         4.0|      6.0|    (6,[],[])|
# | 13| 0.22|  Premium|    F|    SI1| 60.4| 61.0|  342|3.88|3.84|2.33|   1.0|        SIb|         2.0|      2.0|(6,[2],[1.0])|
# | 14| 0.31|    Ideal|    J|    SI2| 62.2| 54.0|  344|4.35|4.37|2.71|   0.0|        SIa|         1.0|      6.0|    (6,[],[])|
# | 15|  0.2|  Premium|    E|    SI2| 60.2| 62.0|  345|3.79|3.75|2.27|   1.0|        SIa|         1.0|      1.0|(6,[1],[1.0])|
# | 16| 0.32|  Premium|    E|     I1| 60.9| 58.0|  345|4.38|4.42|2.68|   1.0|         Ib|         0.0|      1.0|(6,[1],[1.0])|
# | 17|  0.3|    Ideal|    I|    SI2| 62.0| 54.0|  348|4.31|4.34|2.68|   0.0|        SIa|         1.0|      5.0|(6,[5],[1.0])|
# | 18|  0.3|     Good|    J|    SI1| 63.4| 54.0|  351|4.23|4.29| 2.7|   3.0|        SIb|         2.0|      6.0|    (6,[],[])|
# | 19|  0.3|     Good|    J|    SI1| 63.8| 56.0|  351|4.23|4.26|2.71|   3.0|        SIb|         2.0|      6.0|    (6,[],[])|
# | 20|  0.3|Very Good|    J|    SI1| 62.7| 59.0|  351|4.21|4.27|2.66|   2.0|        SIb|         2.0|      6.0|    (6,[],[])|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+-------------+
# only showing top 20 rows

# %%
from pyspark.ml.functions import vector_to_array
df_train = df_pre_train.withColumn("one_hot", vector_to_array(col("Color_Encoded")))

# %%
df_train.show()
# Out:
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+-------------+--------------------+
# |_c0|carat|      cut|color|clarity|depth|table|price|   x|   y|   z|target|Ord_Clarity|feat_clarity|Ord_Color|Color_Encoded|             one_hot|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+-------------+--------------------+
# |  1| 0.23|    Ideal|    E|    SI2| 61.5| 55.0|  326|3.95|3.98|2.43|   0.0|        SIa|         1.0|      1.0|(6,[1],[1.0])|[0.0, 1.0, 0.0, 0...|
# |  2| 0.21|  Premium|    E|    SI1| 59.8| 61.0|  326|3.89|3.84|2.31|   1.0|        SIb|         2.0|      1.0|(6,[1],[1.0])|[0.0, 1.0, 0.0, 0...|
# |  3| 0.23|     Good|    E|    VS1| 56.9| 65.0|  327|4.05|4.07|2.31|   3.0|        VSb|         4.0|      1.0|(6,[1],[1.0])|[0.0, 1.0, 0.0, 0...|
# |  4| 0.29|  Premium|    I|    VS2| 62.4| 58.0|  334| 4.2|4.23|2.63|   1.0|        VSa|         3.0|      5.0|(6,[5],[1.0])|[0.0, 0.0, 0.0, 0...|
# |  5| 0.31|     Good|    J|    SI2| 63.3| 58.0|  335|4.34|4.35|2.75|   3.0|        SIa|         1.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|
# |  6| 0.24|Very Good|    J|   VVS2| 62.8| 57.0|  336|3.94|3.96|2.48|   2.0|       VVSa|         5.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|
# |  7| 0.24|Very Good|    I|   VVS1| 62.3| 57.0|  336|3.95|3.98|2.47|   2.0|       VVSb|         6.0|      5.0|(6,[5],[1.0])|[0.0, 0.0, 0.0, 0...|
# |  8| 0.26|Very Good|    H|    SI1| 61.9| 55.0|  337|4.07|4.11|2.53|   2.0|        SIb|         2.0|      4.0|(6,[4],[1.0])|[0.0, 0.0, 0.0, 0...|
# |  9| 0.22|     Fair|    E|    VS2| 65.1| 61.0|  337|3.87|3.78|2.49|   4.0|        VSa|         3.0|      1.0|(6,[1],[1.0])|[0.0, 1.0, 0.0, 0...|
# | 10| 0.23|Very Good|    H|    VS1| 59.4| 61.0|  338| 4.0|4.05|2.39|   2.0|        VSb|         4.0|      4.0|(6,[4],[1.0])|[0.0, 0.0, 0.0, 0...|
# | 11|  0.3|     Good|    J|    SI1| 64.0| 55.0|  339|4.25|4.28|2.73|   3.0|        SIb|         2.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|
# | 12| 0.23|    Ideal|    J|    VS1| 62.8| 56.0|  340|3.93| 3.9|2.46|   0.0|        VSb|         4.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|
# | 13| 0.22|  Premium|    F|    SI1| 60.4| 61.0|  342|3.88|3.84|2.33|   1.0|        SIb|         2.0|      2.0|(6,[2],[1.0])|[0.0, 0.0, 1.0, 0...|
# | 14| 0.31|    Ideal|    J|    SI2| 62.2| 54.0|  344|4.35|4.37|2.71|   0.0|        SIa|         1.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|
# | 15|  0.2|  Premium|    E|    SI2| 60.2| 62.0|  345|3.79|3.75|2.27|   1.0|        SIa|         1.0|      1.0|(6,[1],[1.0])|[0.0, 1.0, 0.0, 0...|
# | 16| 0.32|  Premium|    E|     I1| 60.9| 58.0|  345|4.38|4.42|2.68|   1.0|         Ib|         0.0|      1.0|(6,[1],[1.0])|[0.0, 1.0, 0.0, 0...|
# | 17|  0.3|    Ideal|    I|    SI2| 62.0| 54.0|  348|4.31|4.34|2.68|   0.0|        SIa|         1.0|      5.0|(6,[5],[1.0])|[0.0, 0.0, 0.0, 0...|
# | 18|  0.3|     Good|    J|    SI1| 63.4| 54.0|  351|4.23|4.29| 2.7|   3.0|        SIb|         2.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|
# | 19|  0.3|     Good|    J|    SI1| 63.8| 56.0|  351|4.23|4.26|2.71|   3.0|        SIb|         2.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|
# | 20|  0.3|Very Good|    J|    SI1| 62.7| 59.0|  351|4.21|4.27|2.66|   2.0|        SIb|         2.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+-------------+--------------------+
# only showing top 20 rows

# %%
features_in = ["table","depth","feat_clarity","price","Color_Encoded"]
vector = VectorAssembler(inputCols= features_in, outputCol= "Vector_Features")

# %%
data_full = vector.transform(df_train)

# %%
train,test = data_full.randomSplit((0.7,0.3))

# %%
from pyspark.ml.classification import RandomForestClassifier

num_tress = [10]

models = {}

for indice,tress in enumerate(num_tress):
    model = RandomForestClassifier(featuresCol="Vector_Features", labelCol= "target", numTrees = tress)
    models["modelo_{}".format(indice)] = model.fit(train)

# %%
evaluations = {}
for indice in range(len(models)):
    evaluations["modelo_{}".format(indice)] = models["modelo_{}".format(indice)].evaluate(test)

# %%
for indice in range(len(models)):
    print("Evaluacion Modelo con {} estimadores".format(num_tress[indice]))
    print("Class\tPrecision\tRecall")
    print("-"*30)
    for clase,precision,recall in zip(model_indexer.labels, evaluations["modelo_{}".format(indice)].precisionByLabel, evaluations["modelo_{}".format(indice)].recallByLabel):
        print("%s\t%.3f\t%.3f" %(clase,precision,recall))
    print()
    print("Accuracy medio: %.3f" %(evaluations["modelo_{}".format(indice)].accuracy))
    print("*"*30)
# Out:
# Evaluacion Modelo con 10 estimadores
# Class	Precision	Recall
# ------------------------------
# Ideal	0.790	0.944
# Premium	0.608	0.873
# Very Good	0.568	0.165
# Good	0.590	0.438
# Fair	0.722	0.545
#
# Accuracy medio: 0.694
# ******************************

# %%
gbt_clf = GBTClassifier(maxIter= 20)

# %%
multi_clf = OneVsRest(classifier = gbt_clf, featuresCol="Vector_Features", labelCol="target")

# %%
model = multi_clf.fit(train)

# %%
predictions = model.transform(test)

# %%
predictions.show()
# Out:
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+-------------
0|      5.0|(6,[5],[1.0])|[0.0, 0.0, 0.0, 0...|(10,[0,1,2,3,9],[...|[0.83879205822434...|       0.0|
# | 56|  0.3|    Ideal|    I|    SI2| 61.0| 59.0|  405| 4.3|4.33|2.63|   0.0|        SIa|         1.0|      5.0|(6,[5],[1.0])|[0.0, 0.0, 0.0, 0...|(10,[0,1,2,3,9],[...|[-1.1818858965090...|       1.0|
# | 57|  0.3|  Premium|    J|    SI2| 59.3| 61.0|  405|4.43|4.38|2.61|   1.0|        SIa|         1.0|      6.0|    (6,[],[])|[0.0, 0.0, 0.0, 0...|(10,[0,1,2,3],[61...|[-1.4302430505844...|       2.0|
# | 59|  0.3|Very Good|    I|    SI1| 63.0| 57.0|  405|4.28|4.32|2.71|   2.0|        SIb|         2.0|      5.0|(6,[5],[1.0])|[0.0, 0.0, 0.0, 0...|(10,[0,1,2,3,9],[...|[-0.6269223972743...|       2.0|
# | 64|  0.3|    Ideal|    D|    SI1| 62.1| 56.0|  552| 4.3|4.33|2.68|   0.0|        SIb|         2.0|      0.0|(6,[0],[1.0])|[1.0, 0.0, 0.0, 0...|(10,[0,1,2,3,4],[...|[0.93338448167778...|       0.0|
# | 66| 0.28|    Ideal|    G|   VVS2| 61.4| 56.0|  553|4.19|4.22|2.58|   0.0|       VVSa|         5.0|      3.0|(6,[3],[1.0])|[0.0, 0.0, 0.0, 1...|(10,[0,1,2,3,7],[...|[0.64852060597945...|       0.0|
# | 69| 0.31|  Premium|    G|    SI1| 61.8| 58.0|  553|4.35|4.32|2.68|   1.0|        SIb|         2.0|      3.0|(6,[3],[1.0])|[0.0, 0.0, 0.0, 1...|(10,[0,1,2,3,7],[...|[-1.0077124270497...|       1.0|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+------+-----------+------------+---------+-------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
clases = {valor["cut"]: valor["target"] for valor in predictions.select("target","cut").distinct().collect() }

# %%
print(clases)
# Out:
# {'Fair': 4.0, 'Very Good': 2.0, 'Good': 3.0, 'Ideal': 0.0, 'Premium': 1.0}

# %%
eval = MulticlassClassificationEvaluator(predictionCol="prediction",labelCol="target", metricName="accuracy")
precision_by_label = {}
recall_by_label = {}
for name,label in clases.items():
    eval.setMetricLabel(label)
    for dicc,metric in zip([precision_by_label, recall_by_label],["precisionByLabel", "recallByLabel"]):
        eval.setMetricName(metric)
        dicc[name] = eval.evaluate(predictions)
eval.setMetricName("accuracy")
acc = eval.evaluate(predictions)
# Out:
# Clase	Precision	Recall
# -------------------------
# Fair	0.68	0.80
# Very Good	0.62	0.29
# Good	0.64	0.53
# Ideal	0.81	0.93
# Premium	0.64	0.83
# Avg. Accuracy: 0.72

# %%
print("Clase\tPrecision\tRecall")
print("-"*25)
for name in clases:
    print("%s\t%.2f\t%.2f" %(name,precision_by_label[name],recall_by_label[name]))
print("Total Accuracy: %.2f" %(mean_acc))
# Out:
# Clase	Precision	Recall
# -------------------------
# Fair	0.68	0.80
# Very Good	0.62	0.29
# Good	0.64	0.53
# Ideal	0.81	0.93
# Premium	0.64	0.83
# Total Accuracy: 0.72

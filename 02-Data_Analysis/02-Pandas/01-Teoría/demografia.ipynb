# %%
import pandas as pd

demo = pd.read_csv("data/demografia.csv", encoding="latin-1", sep=";", dtype={"Total": str})

# %%
demo.head()
# Out:
#      edad         sexo nacionalidad  anno    total
# 0  0 años  Ambos sexos        TOTAL  2022  320.653
# 1  0 años  Ambos sexos        TOTAL  2021  322.549
# 2  0 años  Ambos sexos        TOTAL  2020  343.126
# 3  0 años  Ambos sexos        TOTAL  2019  356.459
# 4  0 años  Ambos sexos        TOTAL  2018  377.865

# %%
demo.columns = ["edad", "sexo", "nacionalidad", "anno", "total"]

# %%
demo['total'].values[0:20]
# Out:
# array(['320.653', '322.549', '343.126', '356.459', '377.865', '394.496',
#        '402.077', '407.249', '406.750', '431.788', '444.251', '460.270',
#        '468.731', '484.176', '452.016', '424.058', '423.881', '405.687',
#        '373.876', '367.822'], dtype=object)

# %%
demo.describe()
# Out:
#               anno
# count  2525.000000
# mean   2010.000000
# std       7.212531
# min    1998.000000
# 25%    2004.000000
# 50%    2010.000000
# 75%    2016.000000
# max    2022.000000

# %%
demo['total']
# Out:
# 0       320.653
# 1       322.549
# 2       343.126
# 3       356.459
# 4       377.865
#          ...
# 2520      8.719
# 2521      8.766
# 2522      5.760
# 2523      4.680
# 2524      3.474
# Name: total, Length: 2525, dtype: float64

# %%
demo.describe(include="all")
# Out:
#           edad         sexo nacionalidad         anno        total
# count     2525         2525         2525  2525.000000  2525.000000
# unique     101            1            1          NaN          NaN
# top     0 años  Ambos sexos        TOTAL          NaN          NaN
# freq        25         2525         2525          NaN          NaN
# mean       NaN          NaN          NaN  2010.000000   446.549681
# std        NaN          NaN          NaN     7.212531   219.956814
# min        NaN          NaN          NaN  1998.000000     2.008000
# 25%        NaN          NaN          NaN  2004.000000   331.871000
# 50%        NaN          NaN          NaN  2010.000000   463.386000
# 75%        NaN          NaN          NaN  2016.000000   609.868000
# max        NaN          NaN          NaN  2022.000000   850.071000

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   edad    2525 non-null   object
#  1   anno    2525 non-null   int64
#  2   total   2525 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 59.3+ KB

# %%
#Eliminar columnas. Ambas formas funcionan
demo.drop(['sexo', "nacionalidad"], axis=1, inplace=True)
#demo = demo.drop(['sexo', "nacionalidad"], axis=1)

# %%
# Opcion 1
demo["total"] = demo['total']*1000
demo["total"] = demo['total'].astype(int)

# %%
# Opcion 2
#total = demo['total'].astype(str)

# %%
#total_ = total.str.replace(".", "")

# %%
#total_ = total_.astype(int)

# %%
#demo['total'] = total_
# Out:
# 0       320.653
# 1       322.549
# 2       343.126
# 3       356.459
# 4       377.865
#          ...
# 2520      8.719
# 2521      8.766
# 2522      5.760
# 2523      4.680
# 2524      3.474
# Name: total, Length: 2525, dtype: float64

# %%
demo['total'] = demo['total'].str.replace(".", "").astype(float)

# %%
demo.describe()
# Out:
#               anno          total
# count  2525.000000    2525.000000
# mean   2010.000000  446549.680792
# std       7.212531  219956.814197
# min    1998.000000    2008.000000
# 25%    2004.000000  331871.000000
# 50%    2010.000000  463386.000000
# 75%    2016.000000  609868.000000
# max    2022.000000  850071.000000

# %%
demo.head()
# Out:
#      edad  anno   total
# 0  0 años  2022  320653
# 1  0 años  2021  322549
# 2  0 años  2020  343126
# 3  0 años  2019  356459
# 4  0 años  2018  377865

# %%
#Calcular el número de habitantes con 0 años desde 1998
sum(demo[demo['edad']=="0 años"]["total"])
# Out:
# 9637653

# %%
demo[demo['edad']=="0 años"]["total"].sum()
# Out:
# 9637653

# %%
import numpy as np
np.sum(demo[demo['edad']=="0 años"]["total"])
# Out:
# 9637653

# %%
np.nansum(demo[demo['edad']=="0 años"]["total"])
# Out:
# 9637653

# %%
demo[demo['edad']!="0 años"]["total"].sum()
# Out:
# 1117900272

# %%
demo[~(demo['edad']=="0 años")]["total"].sum()
# Out:
# 1117900272

# %%
demo.head()
# Out:
#      edad  anno   total
# 0  0 años  2022  320653
# 1  0 años  2021  322549
# 2  0 años  2020  343126
# 3  0 años  2019  356459
# 4  0 años  2018  377865

# %%
# 14 años en el año 2000
demo[(demo['edad']=="14 años") & (demo['anno'] == 2000)]["total"]
# Out:
# 372    468575
# Name: total, dtype: int32

# %%
demo[demo['anno']==demo['anno'].max()]['total'].sum()
# Out:
# 47475419

# %%
demo[demo['anno']==demo['anno'].min()]['total'].sum()
# Out:
# 39852655

# %%
demo_2022 = demo[demo["anno"] == 2022].copy()

# %%
demo_2022['porc'] = demo_2022['total']/demo_2022['total'].sum()

# %%
demo_2022['porc'].sum()
# Out:
# 1.0

# %%
demo_2022[demo_2022['porc'] == demo_2022['porc'].max()]
# Out:
#          edad  anno   total      porc
# 1125  45 años  2022  818364  0.017238

# %%
demo_2021 = demo[demo["anno"] == 2021].copy()
demo_2021['porc'] = demo_2021['total']/demo_2021['total'].sum()

# %%
demo_2021.head()
# Out:
#        edad  anno   total      porc
# 1    0 años  2021  322549  0.006807
# 26    1 año  2021  358635  0.007569
# 51   2 años  2021  375755  0.007930
# 76   3 años  2021  403954  0.008525
# 101  4 años  2021  426796  0.009007

# %%
demo_2022.head()
# Out:
#        edad  anno   total      porc
# 0    0 años  2022  320653  0.006754
# 25    1 año  2022  340664  0.007176
# 50   2 años  2022  360104  0.007585
# 75   3 años  2022  380995  0.008025
# 100  4 años  2022  407352  0.008580

# %%
demo_22_21 = demo_2021.merge(demo_2022, on=["edad"], suffixes=("_2021", "_2022"))

# %%
demo_22_21[demo_22_21['total_2021'] > demo_22_21['total_2022'] ]
# Out:
#        edad  anno_2021  total_2021  porc_2021  anno_2022  total_2022  \
# 0    0 años       2021      322549   0.006807       2022      320653
# 1     1 año       2021      358635   0.007569       2022      340664
# 2    2 años       2021      375755   0.007930       2022      360104
# 3    3 años       2021      403954   0.008525       2022      380995
# 4    4 años       2021      426796   0.009007       2022      407352
# 5    5 años       2021      438463   0.009253       2022      429243
# 6    6 años       2021      446016   0.009413       2022      441196
# 8    8 años       2021      468286   0.009883       2022      445310
# 9    9 años       2021      481023   0.010151       2022      471747
# 10  10 años       2021      492427   0.010392       2022      483983
# 11  11 años       2021      501019   0.010573       2022      495075
# 12  12 años       2021      524131   0.011061       2022      503693
# 23  23 años       2021      478424   0.010097       2022      473666
# ...

# %%
import pandas as pd

# %%
cuenca = pd.read_csv("data/cuenca.csv", sep=";")

# %%
cuenca
# Out:
#            Municipios     Sexo  Periodo    Total
# 0           16 Cuenca    Total     2023  197.139
# 1           16 Cuenca    Total     2022  195.215
# 2           16 Cuenca    Total     2021  195.516
# 3           16 Cuenca    Total     2020  196.139
# 4           16 Cuenca    Total     2019  196.329
# ...               ...      ...      ...      ...
# 20071  16280 Zarzuela  Mujeres     2000  147.000
# 20072  16280 Zarzuela  Mujeres     1999  150.000
# 20073  16280 Zarzuela  Mujeres     1998  148.000
# 20074  16280 Zarzuela  Mujeres     1997      NaN
# 20075  16280 Zarzuela  Mujeres     1996  153.000
#
# [20076 rows x 4 columns]

# %%
cuenca["Municipios"] = cuenca["Municipios"].apply(lambda x: x.split()[0])

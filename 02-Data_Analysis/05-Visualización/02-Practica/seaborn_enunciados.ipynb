# %% [markdown]
# # Seaborn Exercises
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on in the Machine Learning section of the course, we will revisit this data, and use it to predict survival rates of passengers. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.jointplot(x=titanic['fare'], y=titanic['age'])

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
plt.figure(figsize=(4,3))
sns.histplot(titanic['fare'], bins=30, color='#fa8fb1')
plt.gca().set_ylabel('')  # Esto elimina la etiqueta del eje y
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
nombres_clases = {
    1: 'primera',
    2: 'segunda',
    3: 'tercera'
}

# Cambiar los nombres de las clases en el DataFrame
titanic_temp = titanic.copy()
titanic_temp['pclass'] = titanic_temp['pclass'].map(nombres_clases)

plt.figure(figsize=(4.2,3))
sns.boxplot(x='pclass', y='age',data=titanic_temp ,palette='rainbow', order=['primera', 'segunda', 'tercera'], fliersize=2)
plt.xlabel('Class')
# Out:
# C:\Users\pabma\AppData\Local\Temp\ipykernel_13856\1508565396.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='pclass', y='age',data=titanic_temp ,palette='rainbow', order=['primera', 'segunda', 'tercera'], fliersize=2)
# Text(0.5, 0, 'Class')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
plt.figure(figsize=(1.5, 1.2))
sns.catplot(x='pclass', y='age',data=titanic_temp, kind="swarm" ,palette='rainbow', order=['primera', 'segunda', 'tercera'])
# Out:
# C:\Users\pabma\AppData\Local\Temp\ipykernel_13856\1406972109.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='pclass', y='age',data=titanic_temp, kind="swarm" ,palette='rainbow', order=['primera', 'segunda', 'tercera'])
# c:\Users\pabma\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\pabma\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette='rainbow')
# Out:
# C:\Users\pabma\AppData\Local\Temp\ipykernel_13856\173160962.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='class',y='age',data=titanic,palette='rainbow')
# <Axes: xlabel='class', ylabel='age'>
# c:\Users\pabma\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
plt.figure(figsize=(4.2, 3))
sns.countplot(x='sex', data=titanic, palette=['lightblue', 'orange'])
# Out:
# C:\Users\pabma\AppData\Local\Temp\ipykernel_13856\3687596942.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=titanic, palette=['lightblue', 'orange'])
# <Axes: xlabel='sex', ylabel='count'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
plt.figure(figsize=(4,3))
titanic_copy = titanic.copy()
titanic_copy.drop(columns=['sex', 'embarked', 'class', 'who', 'deck','embark_town','alive'], inplace=True)
sns.heatmap(titanic_copy.corr(),cmap='coolwarm')
plt.title('titanic.corr()')
titanic_copy.columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'adult_male',
#        'alone'],
#       dtype='object')

# %%
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
g = sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist,'age')

# %%
#https://www.kaggle.com/datasets/specter7/amazon-amzn-historical-stock-price-data/

# %% [markdown]
# # FAANG Historical Stock Price Data

# %% [markdown]
# About Dataset
#
# FAANG STOCKS ---> Stocks data of Facebook, Amazon, Apple, Netflix & Google companies.
# CONTENT :
#
# The dataset contains:
# -- The data that was scraped from the yahoo finance website.
# -- Open, Close, Adj Close, High, Low stock prices and Volume of Facebook, Amazon, Apple, Netflix & Google stocks for the last 10 years.
# This dataset contains the stock data of Amazon for the last 5 years (from 2016 to date). The insights from this data can be used to perform data analysis, backtesting various trading strategies & stock price trend prediction.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from os import listdir
from os.path import isfile, join

# %%
path = "./data"
files = [f for f in listdir(path) if isfile(join(path, f))]
files
# Out:
# ['Amazon_Historical_StockPrice2.csv',
#  'Apple_Historical_StockPrice2.csv',
#  'Facebook_Historical_StockPrice2.csv',
#  'Google_Historical_StockPrice2.csv',
#  'Netflix_Historical_StockPrice2.csv']

# %%
faang = pd.DataFrame()
for f in files:
    tmp = pd.read_csv(f"./data/{f}")
    # nueva columna Nombre con el nombre de la compañia
    tmp["Nombre"] = f.split("_")[0]
    faang = pd.concat([faang,tmp])

# %%
faang.to_csv("faang.csv")

# %%
faang.sample(50)
# Out:
#             Date         Open         High          Low        Close  \
# 841   2019-07-30   195.389999   198.710007   193.500000   197.039993
# 786   2019-05-10   361.619995   365.260010   353.059998   361.040009
# 264   2017-04-12   139.720001   140.399994   139.440002   139.580002
# 788   2019-05-14   348.709991   349.950012   342.500000   345.609985
# 596   2018-08-07   186.500000   188.300003   183.720001   183.809998
# 14    2016-04-15   753.979980   761.000000   752.693970   759.000000
# 1127  2020-09-16   267.290009   272.440002   261.790009   263.519989
# 1023  2020-04-20    69.487503    70.419998    69.212502    69.232498
# 123   2016-09-20    28.262501    28.530001    28.127501    28.392500
# 455   2018-01-16    44.474998    44.847500    44.035000    44.047501
# 423   2017-11-28  1055.089966  1062.375000  1040.000000  1047.410034
# 332   2017-07-20    37.875000    37.935001    37.547501    37.584999
# 1143  2020-10-08   259.750000   264.619995   259.149994   263.760010
# ...

# %%
# Fecha!
apple = pd.read_csv("./data/Apple_Historical_StockPrice2.csv", parse_dates=["Date"])

# %%
apple.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2016-03-28  584.400024  584.750000  575.559998  579.869995  579.869995
# 1 2016-03-29  580.150024  595.849976  576.500000  593.859985  593.859985
# 2 2016-03-30  596.710022  603.239990  595.000000  598.690002  598.690002
# 3 2016-03-31  599.280029  600.750000  592.210022  593.640015  593.640015
# 4 2016-04-01  590.489990  599.030029  588.299988  598.500000  598.500000
#
#     Volume
# 0  3121500
# 1  4392600
# 2  3890500
# 3  2681800
# 4  2917400

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1260 non-null   datetime64[ns]
#  1   Open       1260 non-null   float64
#  2   High       1260 non-null   float64
#  3   Low        1260 non-null   float64
#  4   Close      1260 non-null   float64
#  5   Adj Close  1260 non-null   float64
#  6   Volume     1260 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.0 KB

# %%
apple['Date'] = pd.to_datetime(apple['Date'])

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1260 non-null   datetime64[ns]
#  1   Open       1260 non-null   float64
#  2   High       1260 non-null   float64
#  3   Low        1260 non-null   float64
#  4   Close      1260 non-null   float64
#  5   Adj Close  1260 non-null   float64
#  6   Volume     1260 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.0 KB

# %%
apple.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2016-03-28  584.400024  584.750000  575.559998  579.869995  579.869995
# 1 2016-03-29  580.150024  595.849976  576.500000  593.859985  593.859985
# 2 2016-03-30  596.710022  603.239990  595.000000  598.690002  598.690002
# 3 2016-03-31  599.280029  600.750000  592.210022  593.640015  593.640015
# 4 2016-04-01  590.489990  599.030029  588.299988  598.500000  598.500000
#
#     Volume
# 0  3121500
# 1  4392600
# 2  3890500
# 3  2681800
# 4  2917400

# %%
faang['Date'] = pd.to_datetime(faang['Date'])

# %%
fig, ax = plt.subplots()
ax.plot(faang[faang['Nombre']=="Netflix"]['Date'], faang[faang['Nombre']=="Netflix"]['Close'])
ax.plot(faang[faang['Nombre']=="Apple"]['Date'], faang[faang['Nombre']=="Apple"]['Close'])
ax.plot(faang[faang['Nombre']=="Google"]['Date'], faang[faang['Nombre']=="Google"]['Close'])

# %%
fig, ax = plt.subplots()
for n in faang['Nombre'].unique():
    ax.plot(faang[faang['Nombre']==n]['Date'], faang[faang['Nombre']==n]['Close'], lw=1)
ax.legend(faang['Nombre'].unique())
ax.vlines(pd.to_datetime(['2020-01-01']), 0, 4000, colors="black")
ax.set_title("Cotización FAANG")
# Out:
# Text(0.5, 1.0, 'Cotización FAANG')

# %%
faang[faang['Nombre']=="Netflix"].max()
# Out:
# Date         2021-03-26 00:00:00
# Open                  582.450012
# High                  593.289978
# Low                   570.400024
# Close                 586.340027
# Adj Close             586.340027
# Volume                  58410400
# Nombre                   Netflix
# dtype: object

# %%
fig, ax = plt.subplots()
ax.plot(faang[faang['Nombre']=="Netflix"]['Date'], faang[faang['Nombre']=="Netflix"]['Close'])
ax.plot(faang[faang['Nombre']=="Apple"]['Date'], faang[faang['Nombre']=="Apple"]['Close'])
ax.plot(faang[faang['Nombre']=="Google"]['Date'], faang[faang['Nombre']=="Google"]['Close'])

# %%
fig, ax = plt.subplots()
ax.plot('Date', 'Close', data=apple)

# %%
fig, ax = plt.subplots()
ax.hist(apple['Volume'], bins=2000);

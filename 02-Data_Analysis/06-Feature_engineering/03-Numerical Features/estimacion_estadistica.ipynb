# %%
import pandas as pd
import numpy as np

# %%
alt = pd.read_csv("alturas.csv")

# %%
mean = []
np.random.seed(42)
for n in range(5000):
    samp = alt['esp'].sample(50)
    mean.append(samp.mean())

# %%
np.mean(mean) - alt['esp'].mean()
# Out:
# -0.0055866113096953995

# %%
alt['esp'].describe()
# Out:
# count    10000.000000
# mean       170.120040
# std         19.915349
# min         96.737075
# 25%        156.657101
# 50%        170.377533
# 75%        183.614256
# max        259.036674
# Name: esp, dtype: float64

# %%
samp.describe()
# Out:
# count     50.000000
# mean     166.683373
# std       19.473951
# min      127.115689
# 25%      150.707586
# 50%      170.298993
# 75%      181.084291
# max      199.338974
# Name: esp, dtype: float64

# %%
alt['esp'].hist()
# Out:
# <Axes: >

# %%
alt['esp'].plot.kde()
# Out:
# <Axes: ylabel='Density'>
